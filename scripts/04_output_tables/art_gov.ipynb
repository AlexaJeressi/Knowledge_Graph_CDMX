# %%
import pandas as pd
import numpy as np
import os

# %%
# Leer las tablas 
# Tabla oficial 
official_gov = pd.read_csv('../../data/04_matched/oficial_gov_matched.csv')
official_gov.info()
official_gov = official_gov[['art_id','entity_id','type_of_relation']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9615 entries, 0 to 9614
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   art_id            9615 non-null   object
#  1   entity_text       9615 non-null   object
#  2   entity_id         9613 non-null   object
#  3   similarity        9615 non-null   float64
#  4   match_type        9613 non-null   object
#  5   type_of_relation  9615 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 450.8+ KB

# %%
# Tabla general

# %%
# Unir las tablas 
#total_gov = official_gov.merge(general_gov, on='art_id', how='outer')

# %%
# Guardar tabla 
total_gov = official_gov
total_gov.to_csv('../../data/05_output/art_gov.csv', index=False)
