# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/03_extracted/legal_documents_with_ids.csv')
df['type_of_relation'] = 'art_parte_doc'
df = df[['art_id','type_of_relation','doc_id']]
df.drop_duplicates(subset=['art_id','doc_id'], keep='first', inplace=True)
print(df.head())
df.to_csv('../../data/05_output/art_parte_doc.csv', index=False)
# Out:
#        art_id type_of_relation    doc_id
# 0  6D0C4493_1    art_parte_doc  6D0C4493
# 1  6D0C4493_2    art_parte_doc  6D0C4493
# 2  6D0C4493_3    art_parte_doc  6D0C4493
# 3  6D0C4493_4    art_parte_doc  6D0C4493
# 4  6D0C4493_5    art_parte_doc  6D0C4493
