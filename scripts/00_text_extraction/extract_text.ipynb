# %% [markdown]
# # Extracción de Texto de Documentos Legales
#
# ## Objetivo
# Este notebook extrae artículos individuales de documentos legales (PDFs y DOCX) y los guarda en un formato estructurado.
#
# ## Salida
# - **Archivo**: Nombre del archivo sin extensión
# - **Articulo**: Número/nombre del artículo
# - **Texto**: Contenido del artículo
#
# ## Funcionalidades principales:
#
# ### Limpieza de contenido:
# 1. **`separar_transitorios`**: Separa artículos transitorios del cuerpo principal
# 2. **`quitar_encabezados_conservador`**: Elimina encabezados estructurales (CAPÍTULO, TÍTULO, etc.)
# 3. **`limpiar_contenido_articulo`**: Limpia encabezados residuales DENTRO de cada artículo
#    - Protege líneas entre paréntesis (ej: DEROGADO, REFORMADO)
#    - Protege palabras clave de estado
#
# ### Extracción de PDFs:
# - Opción de recortar encabezados/pies de página antes de extraer texto
# - Usa PyMuPDF para crear un PDF temporal sin headers/footers
# - Luego extrae texto limpio con Apache Tika
#
# **Nota**: El matching con el catálogo de leyes y la creación de IDs se hace en el siguiente paso (`hash_creation.ipynb`)

# %%
import os
import re
import pandas as pd
from unicodedata import normalize
from tika import parser
from docx import Document
import tempfile
import fitz  # PyMuPDF

# %%
def normaliza_texto(s: str) -> str:
    """
    Normalización básica de texto.
    Unifica espacios especiales y normaliza unicode.
    """
    if not s: 
        return s
    s = normalize("NFKC", s)
    # NBSP y otros espacios duros
    s = s.replace("\u00A0"," ").replace("\u2007"," ").replace("\u202F"," ")
    # opcional: unificar "°" -> "º"
    s = s.replace("°", "º")
    return s

# %%
# Detecta encabezados principales de "Transitorios" en línea aislada
RE_TRANS_HEADER = re.compile(
    r'(?im)^\s*(?:DISPOSICIONES\s+TRANSITORIAS|ART[IÍ]CULOS?\s+TRANSITORIOS?|TRANSITORIOS?)\s*[:\-–—]?\s*$'
)

def separar_transitorios(texto: str) -> tuple:
    """
    Separa el texto en dos partes: texto principal y transitorios.
    
    Returns:
        tuple: (texto_principal, texto_transitorios)
        - texto_principal: texto antes del encabezado TRANSITORIOS
        - texto_transitorios: texto después del encabezado TRANSITORIOS (sin el encabezado)
                              None si no hay transitorios
    """
    if not texto:
        return texto, None

    # Buscar encabezado de TRANSITORIOS
    m = RE_TRANS_HEADER.search(texto)
    if m:
        # Separar en texto principal y transitorios
        texto_principal = texto[:m.start()].rstrip()
        # Capturar todo después del encabezado (sin incluir el encabezado mismo)
        texto_transitorios = texto[m.end():].strip()
        return texto_principal, texto_transitorios
    
    # No hay transitorios
    return texto, None

# %%
# Patrón mejorado: Encabezados estructurales con subtítulo opcional
RE_ESTRUCTURA_MEJORADO = re.compile(r'''
(?:^|\n)                                    # inicio o nueva línea
[ \t]*                                      # espacios/tabs opcionales
(?:                                         # Palabra clave del encabezado
  T[ÍI]TULO | TITULO |
  CAP[ÍI]TULO | CAPITULO |
  SECCI[ÓO]N | SECCION |
  LIBRO
)
\s+
(?:                                         # N° romano, arábigo u ordinal
  [IVXLCDM]+ | \d+ |
  PRIMERO|SEGUNDO|TERCERO|CUARTO|QUINTO|SEXTO|
  S[EÉ]PTIMO|OCTAVO|NOVENO|D[EÉ]CIMO|UND[EÉ]CIMO|DUOD[EÉ]CIMO
)
(?:[^\n]{0,100})?                           # resto de la línea del encabezado
\s*\n
(?:                                         # Subtítulo opcional (siguiente línea)
  [ \t]*
  [A-ZÁÉÍÓÚÑ][A-ZÁÉÍÓÚÑ0-9\s\.\,\-–—:/()']{5,120}  # línea en mayúsculas (subtítulo)
  \s*\n
)?
''', re.MULTILINE | re.VERBOSE)

def quitar_encabezados_conservador(texto: str) -> str:
    """
    Versión MEJORADA: Elimina encabezados estructurales con sus subtítulos.
    - Detecta CAPÍTULO/TÍTULO/SECCIÓN + número
    - Captura subtítulo opcional en la siguiente línea (si está en MAYÚSCULAS)
    - Protege contenido que no sea encabezado
    """
    if not texto:
        return texto

    # Elimina encabezados y sus subtítulos
    t = RE_ESTRUCTURA_MEJORADO.sub("\n", texto)
    
    # Limpia saltos de línea excesivos
    t = re.sub(r"\n{3,}", "\n\n", t).strip()
    return t

# %%
def limpiar_contenido_articulo(contenido: str) -> str:
    """
    Limpia el contenido DENTRO de un artículo ya extraído.
    Elimina encabezados residuales, normaliza espacios y saltos de línea.
    """
    if not contenido:
        return contenido
    
    # 1. Eliminar líneas completas en MAYÚSCULAS (probables encabezados residuales)
    lineas = contenido.split('\n')
    lineas_limpias = []
    
    for linea in lineas:
        linea_stripped = linea.strip()
        
        # Skip líneas vacías (las conservamos)
        if not linea_stripped:
            lineas_limpias.append(linea)
            continue
        
        # Skip líneas muy cortas o muy largas
        if len(linea_stripped) < 5 or len(linea_stripped) > 150:
            lineas_limpias.append(linea)
            continue
        
        # PROTEGER líneas entre paréntesis (anotaciones como DEROGADO, REFORMADO, etc.)
        if linea_stripped.startswith('('):
            lineas_limpias.append(linea)
            continue
        
        # PROTEGER líneas con palabras clave de estado de artículos
        palabras_estado = ['DEROGADO', 'REFORMADO', 'ADICIONADO', 'MODIFICADO', 
                          'ABROGADO', 'FE DE ERRATAS', 'G.O.', 'GACETA OFICIAL']
        if any(palabra in linea_stripped.upper() for palabra in palabras_estado):
            lineas_limpias.append(linea)
            continue
        
        # Contar letras mayúsculas vs total de letras
        letras_mayus = sum(1 for c in linea_stripped if c.isupper())
        letras_minus = sum(1 for c in linea_stripped if c.islower())
        total_letras = letras_mayus + letras_minus
        
        # Si tiene letras y al menos 80% son mayúsculas -> probable encabezado
        if total_letras >= 3 and (letras_mayus / total_letras) >= 0.80:
            # Verificación adicional: no debe empezar con números romanos sueltos
            # (para proteger fracciones como "I. TEXTO", "II. TEXTO")
            if not re.match(r'^[IVXLCDM]{1,4}[\.\)]\s', linea_stripped):
                # Es un encabezado en MAYÚSCULAS, lo omitimos
                continue
        
        # Conservar la línea
        lineas_limpias.append(linea)
    
    contenido = '\n'.join(lineas_limpias)
    
    # 2. Normaliza espacios múltiples
    contenido = re.sub(r'[ \t]+', ' ', contenido)
    
    # 3. Normaliza saltos de línea excesivos
    contenido = re.sub(r'\n{3,}', '\n\n', contenido)
    
    return contenido.strip()

# %%
def extraer_texto_docx(ruta_docx):
    """ Extrae el texto de un archivo .docx """
    try:
        doc = Document(ruta_docx)
        return "\n".join([p.text for p in doc.paragraphs]).strip()
    except Exception as e:
        print(f"Error al procesar '{ruta_docx}': {e}")
        return None

def extraer_texto_pdf(ruta_pdf):
    """ Extrae el texto de un PDF usando Apache Tika """
    try:
        raw = parser.from_file(ruta_pdf)  
        return raw.get("content", "").strip()
    except Exception as e:
        print(f"Error al procesar '{ruta_pdf}': {e}")
        return None

# %%
def extraer_articulos(texto):
    """ 
    Extrae menciones completas de artículos (ej: "Artículo 23 Bis") de documentos 
    legales de la Ciudad de México. Solo captura menciones que inician con A mayúscula
    al principio de línea para evitar menciones en medio del texto.
    """
    if not texto:
        return []

    # PATRÓN COMPLEJO para artículos legales
    # Captura la mención COMPLETA: "Artículo 23 Bis" (no solo "23 Bis")
    patron = r'''
        (?:^|\n)\s*                          # Inicio de línea o nueva línea
        (                                     # GRUPO 1: Mención COMPLETA del artículo
            (?:ART[ÍI]CULO|Art[íi]culo|ARTICULO|Articulo|Art\.)  # Palabra "Artículo"
            \s+                               # Espacios obligatorios
            \d+                               # Número base (ej: 23)
            (?:\s*[°ºªo])?                    # Símbolo de grado opcional (incluye 'o')
            (?:                               # Sufijos opcionales - inicio grupo
                \s+(?:B|T|Q|S|O|D)\s+\d+      # Abreviatura + número OBLIGATORIO (B 1, T 2, etc.)
                |
                \s+(?:B|T|Q|S|O|D)(?!\s+\d)   # Abreviatura SIN número después (155 B, sin fracción)
                |
                \s+[A-Z](?![a-z])             # Espacio + letra MAYÚSCULA (ej: 272 A, 272 C)
                |
                \s*[-–—]\s*[A-Z]              # Guión + letra (ej: 8o-A, 8o-B)
                |
                \s*[-–—]\s*\d+                # Guión + número (ej: 23-1, 23-2)
                |
                \s+(?:BIS|Bis|bis|TER|Ter|ter|QU[ÁA]TER|Qu[áa]ter|quater|
                      QUINTUS|Quintus|quintus|QUINQUIES|Quinquies|quinquies|QUINTIES|Quinties|quinties|
                      SEXTUS|Sextus|sextus|SEXIES|Sexies|sexies|SEXTIES|Sexties|sexties|
                      SEPTIMUS|Septimus|septimus|SEPTIES|Septies|septies|SEPTIESEP|Septiesep|septiesep|
                      OCTAVUS|Octavus|octavus|OCTIES|Octies|octies|
                      NON[IÍ]ES|Non[ií]es|non[ií]es|NOVIES|Novies|novies|
                      DEC[IÍ]ES|Dec[ií]es|dec[ií]es|DECIMUS|Decimus|decimus|
                      UNDECIES|Undecies|undecies|DUODECIES|Duodecies|duodecies)\s+\d+  # Ordinal + número
                |
                \s+(?:BIS|Bis|bis|TER|Ter|ter|QU[ÁA]TER|Qu[áa]ter|quater|
                      QUINTUS|Quintus|quintus|QUINQUIES|Quinquies|quinquies|QUINTIES|Quinties|quinties|
                      SEXTUS|Sextus|sextus|SEXIES|Sexies|sexies|SEXTIES|Sexties|sexties|
                      SEPTIMUS|Septimus|septimus|SEPTIES|Septies|septies|SEPTIESEP|Septiesep|septiesep|
                      OCTAVUS|Octavus|octavus|OCTIES|Octies|octies|
                      NON[IÍ]ES|Non[ií]es|non[ií]es|NOVIES|Novies|novies|
                      DEC[IÍ]ES|Dec[ií]es|dec[ií]es|DECIMUS|Decimus|decimus|
                      UNDECIES|Undecies|undecies|DUODECIES|Duodecies|duodecies)  # Ordinal sin número
            )?                                # Sufijos opcionales - fin grupo (OPCIONAL)
            \s*                               # Espacios opcionales
            [.:\-–—°]?                       # Separadores opcionales
            \s*                               # Espacios opcionales
            [-–—]?                           # Guión adicional opcional
        )
        \s*                                   # Espacios después de la mención
        (?=\S)                                # Lookahead: debe seguir contenido
        (.*?)                                 # GRUPO 2: Contenido del artículo (no greedy)
        (?=                                   # Lookahead: termina cuando encuentra:
            (?:\n\s*(?:ART[ÍI]CULO|Art[íi]culo|ARTICULO|Articulo|Art\.)\s+\d+)  # Siguiente artículo
            |
            (?:\n\s*(?:CAP[ÍI]TULO|Cap[íi]tulo|CAPITULO|Capitulo|TÍTULO|T[ií]tulo|TITULO))  # Nuevo capítulo/título
            |
            (?:\n\s*(?:TRANSITORIOS?|Transitorios?))  # Artículos transitorios
            |
            \Z                                # Fin del texto
        )
    '''

    articulos = []
    matches = re.finditer(patron, texto, re.MULTILINE | re.DOTALL | re.VERBOSE)
    
    for match in matches:
        mencion_completa = match.group(1).strip()  # "Artículo 23 Bis"
        contenido = match.group(2).strip() if match.group(2) else ""
        
        # Verifica que la mención inicie con A mayúscula
        if not mencion_completa[0].isupper():
            continue
        
        # Limpia el contenido del artículo
        contenido = limpiar_contenido_articulo(contenido)
        
        # Normaliza la mención completa
        mencion_normalizada = normalizar_mencion_articulo(mencion_completa)
        
        articulos.append({
            "Articulo": mencion_normalizada,
            "Articulo_Original": mencion_completa,
            "Texto": contenido
        })

    # Valida la secuencia de artículos
    articulos_validados = validar_secuencia_articulos(articulos)
    
    return articulos_validados


def normalizar_mencion_articulo(mencion):
    """
    Normaliza la mención completa del artículo.
    Ejemplos: 
    - 'ARTICULO 23 BIS' -> 'Artículo 23 Bis'
    - 'Artículo 155 B' -> 'Artículo 155 Bis'
    - 'Artículo 155 B 1' -> 'Artículo 155 Bis 1'
    - 'Art. 23-1' -> 'Artículo 23-1'
    """
    mencion = mencion.strip()
    
    # Normaliza la palabra "Artículo"
    mencion = re.sub(r'^(?:ART[ÍI]CULO|ARTICULO|Art\.)', 'Artículo', mencion, flags=re.IGNORECASE)
    
    # Expande abreviaturas de ordinales (B → Bis, T → Ter, etc.)
    # Captura también el número opcional después de la abreviatura
    mencion = re.sub(r'\b B(\s+\d+)?\b', r' Bis\1', mencion)
    mencion = re.sub(r'\b T(\s+\d+)?\b', r' Ter\1', mencion)
    mencion = re.sub(r'\b Q(\s+\d+)?\b', r' Quáter\1', mencion)
    mencion = re.sub(r'\b S(\s+\d+)?\b', r' Sexies\1', mencion)
    mencion = re.sub(r'\b O(\s+\d+)?\b', r' Octies\1', mencion)
    mencion = re.sub(r'\b D(\s+\d+)?\b', r' Decies\1', mencion)
    
    # Normaliza ordinales latinos a formato estándar
    ordinales = {
        'bis': 'Bis', 'ter': 'Ter', 'quater': 'Quáter', 'quáter': 'Quáter',
        'quintus': 'Quintus', 'quinquies': 'Quinquies', 'quinties': 'Quinties',
        'sextus': 'Sextus', 'sexies': 'Sexies', 'sexties': 'Sexties',
        'septimus': 'Septimus', 'septies': 'Septies', 'septiesep': 'Septies',
        'octavus': 'Octavus', 'octies': 'Octies',
        'nonies': 'Nonies', 'noníes': 'Nonies', 'novies': 'Novies',
        'decies': 'Decies', 'decíes': 'Decies', 'decimus': 'Decimus',
        'undecies': 'Undecies', 'duodecies': 'Duodecies'
    }
    
    for ordinal_min, ordinal_norm in ordinales.items():
        mencion = re.sub(r'\b' + ordinal_min + r'\b', ordinal_norm, mencion, flags=re.IGNORECASE)
    
    # Limpia espacios múltiples
    mencion = re.sub(r'\s+', ' ', mencion)
    
    # Elimina puntos y guiones finales innecesarios
    mencion = re.sub(r'[\.\-–—]+\s*$', '', mencion)
    
    return mencion


def parsear_articulo(mencion):
    """
    Extrae los componentes de un artículo para comparación.
    Retorna: (numero_base, sufijo_ordinal, numero_ordinal, fraccion, letra_sufijo)
    
    Ejemplos:
    - "Artículo 449" → (449, None, None, None, None)
    - "Artículo 449 Bis" → (449, "Bis", None, None, None)
    - "Artículo 449 Bis 2" → (449, "Bis", 2, None, None)
    - "Artículo 498 Bis 6" → (498, "Bis", 6, None, None)
    - "Artículo 23-1" → (23, None, None, 1, None)
    - "Artículo 8o-A" → (8, None, None, None, "A")
    - "Artículo 272 A" → (272, None, None, None, "A")
    - "Artículo 155 Bis" → (155, "Bis", None, None, None)
    - "Artículo 155 Bis 1" → (155, "Bis", 1, None, None)
    """
    # Extrae número base (incluyendo símbolo de grado opcional)
    match_base = re.search(r'Artículo\s+(\d+)[°ºªo]?', mencion)
    if not match_base:
        return None
    
    numero_base = int(match_base.group(1))
    
    # Extrae sufijo ordinal - LISTA COMPLETA
    ordinales_pattern = r'\b(BIS|Bis|bis|TER|Ter|ter|QU[ÁA]TER|Qu[áa]ter|quater|' \
                       r'QUINTUS|Quintus|quintus|QUINQUIES|Quinquies|quinquies|QUINTIES|Quinties|quinties|' \
                       r'SEXTUS|Sextus|sextus|SEXIES|Sexies|sexies|SEXTIES|Sexties|sexties|' \
                       r'SEPTIMUS|Septimus|septimus|SEPTIES|Septies|septies|SEPTIESEP|Septiesep|septiesep|' \
                       r'OCTAVUS|Octavus|octavus|OCTIES|Octies|octies|' \
                       r'NON[IÍ]ES|Non[ií]es|non[ií]es|NOVIES|Novies|novies|' \
                       r'DEC[IÍ]ES|Dec[ií]es|dec[ií]es|DECIMUS|Decimus|decimus|' \
                       r'UNDECIES|Undecies|undecies|DUODECIES|Duodecies|duodecies)\b'
    
    match_ordinal = re.search(ordinales_pattern, mencion, re.IGNORECASE)
    sufijo_ordinal = match_ordinal.group(1) if match_ordinal else None
    
    # Normaliza el sufijo ordinal a formato estándar si existe
    if sufijo_ordinal:
        ordinales_normalizacion = {
            'bis': 'Bis', 'ter': 'Ter', 'quater': 'Quáter', 'quáter': 'Quáter',
            'quintus': 'Quintus', 'quinquies': 'Quinquies', 'quinties': 'Quinties',
            'sextus': 'Sextus', 'sexies': 'Sexies', 'sexties': 'Sexties',
            'septimus': 'Septimus', 'septies': 'Septies', 'septiesep': 'Septies',
            'octavus': 'Octavus', 'octies': 'Octies',
            'nonies': 'Nonies', 'noníes': 'Nonies', 'novies': 'Novies',
            'decies': 'Decies', 'decíes': 'Decies', 'decimus': 'Decimus',
            'undecies': 'Undecies', 'duodecies': 'Duodecies'
        }
        sufijo_ordinal = ordinales_normalizacion.get(sufijo_ordinal.lower(), sufijo_ordinal.capitalize())
    
    # Extrae número después del ordinal (ej: "Bis 2", "Bis 6", "Bis 7")
    numero_ordinal = None
    if sufijo_ordinal:
        match_num_ordinal = re.search(rf'{re.escape(sufijo_ordinal)}\s+(\d+)', mencion, re.IGNORECASE)
        if match_num_ordinal:
            numero_ordinal = int(match_num_ordinal.group(1))
    
    # Extrae letra sufijo (con o sin guión: "8o-A" o "272 A")
    letra_sufijo = None
    match_letra_guion = re.search(r'-([A-Z])\b', mencion)
    if match_letra_guion:
        letra_sufijo = match_letra_guion.group(1)
    elif not sufijo_ordinal:  # Solo busca letra sin guión si NO hay ordinal
        match_letra_espacio = re.search(r'\d+[°ºªo]?\s+([A-Z])\b', mencion)
        if match_letra_espacio:
            letra_sufijo = match_letra_espacio.group(1)
    
    # Extrae fracción numérica (ej: "23-1") - solo si no hay letra ni ordinal
    fraccion = None
    if not letra_sufijo and not sufijo_ordinal:
        match_fraccion = re.search(r'-(\d+)\b', mencion)
        fraccion = int(match_fraccion.group(1)) if match_fraccion else None
    
    return (numero_base, sufijo_ordinal, numero_ordinal, fraccion, letra_sufijo)


def validar_secuencia_articulos(articulos):
    """
    Valida que los artículos sigan una secuencia lógica.
    Detecta posibles errores como:
    - Artículos repetidos sin variación (falta Bis, -1, etc.)
    - Saltos en la numeración sin justificación
    
    Retorna la lista de artículos con advertencias agregadas.
    """
    if len(articulos) < 2:
        return articulos
    
    # Orden de ordinales latinos
    orden_ordinales = {
        None: 0,
        'Bis': 1, 'Ter': 2, 'Quáter': 3, 
        'Quintus': 4, 'Quinquies': 4, 'Quinties': 4,
        'Sextus': 5, 'Sexies': 5, 'Sexties': 5,
        'Septimus': 6, 'Septies': 6, 'Septiesep': 6,
        'Octavus': 7, 'Octies': 7,
        'Nonies': 8, 'Novies': 8,
        'Decies': 9, 'Decimus': 9,
        'Undecies': 10, 'Duodecies': 11
    }
    
    articulos_validados = []
    
    for i, articulo in enumerate(articulos):
        art_actual = parsear_articulo(articulo['Articulo'])
        advertencias = []
        
        if i > 0:
            art_anterior = parsear_articulo(articulos[i-1]['Articulo'])
            
            if art_actual and art_anterior:
                num_base_actual, suf_ord_actual, num_ord_actual, frac_actual, letra_actual = art_actual
                num_base_anterior, suf_ord_anterior, num_ord_anterior, frac_anterior, letra_anterior = art_anterior
                
                # CASO 1: Mismo número base
                if num_base_actual == num_base_anterior:
                    if suf_ord_actual == suf_ord_anterior:
                        if num_ord_actual == num_ord_anterior and frac_actual == frac_anterior and letra_actual == letra_anterior:
                            advertencias.append("⚠️ REPETIDO: Artículo duplicado sin variación")
                        elif num_ord_actual and num_ord_anterior:
                            if num_ord_actual != num_ord_anterior + 1:
                                advertencias.append(f"⚠️ SALTO: Esperaba '{articulos[i-1]['Articulo']}' → 'Artículo {num_base_actual} {suf_ord_actual} {num_ord_anterior + 1}'")
                    elif not suf_ord_anterior and suf_ord_actual:
                        pass  # Transición válida: Art 449 → Art 449 Bis
                    elif letra_actual and letra_anterior:
                        if ord(letra_actual) != ord(letra_anterior) + 1:
                            letra_esperada = chr(ord(letra_anterior) + 1)
                            advertencias.append(f"⚠️ SALTO: Esperaba 'Artículo {num_base_actual} {letra_esperada}'")
                    elif frac_actual and frac_anterior:
                        if frac_actual != frac_anterior + 1:
                            advertencias.append(f"⚠️ SALTO: Esperaba 'Artículo {num_base_actual}-{frac_anterior + 1}'")
                
                # CASO 2: Número base incrementa
                elif num_base_actual == num_base_anterior + 1:
                    pass  # Secuencia normal
                
                # CASO 3: Salto mayor en número base
                elif num_base_actual > num_base_anterior + 1:
                    advertencias.append(f"ℹ️ SALTO NUMÉRICO: De {num_base_anterior} a {num_base_actual}")
                
                # CASO 4: Número base menor
                else:
                    advertencias.append(f"⚠️ RETROCESO: Artículo {num_base_actual} después de {num_base_anterior}")
        
        # Agrega el artículo con sus advertencias
        articulo_validado = articulo.copy()
        if advertencias:
            articulo_validado['Advertencias'] = advertencias
        
        articulos_validados.append(articulo_validado)
    
    return articulos_validados


def limpiar_contenido_articulo(contenido):
    """
    Limpia el contenido del artículo eliminando elementos innecesarios.
    """
    if not contenido:
        return ""
    
    # Elimina saltos de línea excesivos
    contenido = re.sub(r'\n{3,}', '\n\n', contenido)
    
    # Elimina espacios múltiples
    contenido = re.sub(r' {2,}', ' ', contenido)
    
    # Elimina espacios al inicio de cada línea
    lineas = contenido.split('\n')
    lineas_limpias = [linea.strip() for linea in lineas if linea.strip()]
    contenido = '\n'.join(lineas_limpias)
    
    # Elimina caracteres especiales de formateo de PDF
    contenido = re.sub(r'[\x00-\x08\x0b-\x0c\x0e-\x1f]', '', contenido)
    
    return contenido.strip()

# %%
def recortar_pdf_headers_footers(ruta_pdf, crop_top_mm=20, crop_bottom_mm=20):
    """
    Recorta encabezados y pies de página de un PDF.
    
    Args:
        ruta_pdf: Ruta al archivo PDF original
        crop_top_mm: Milímetros a recortar desde arriba (encabezado)
        crop_bottom_mm: Milímetros a recortar desde abajo (pie de página)
    
    Returns:
        Ruta al archivo PDF temporal recortado
    """
    try:
        # Abrir el PDF
        doc = fitz.open(ruta_pdf)
        
        # Crear PDF temporal
        temp_pdf = tempfile.NamedTemporaryFile(delete=False, suffix='.pdf')
        temp_pdf_path = temp_pdf.name
        temp_pdf.close()
        
        # Crear nuevo PDF con páginas recortadas
        pdf_out = fitz.open()
        
        for page_num in range(len(doc)):
            page = doc[page_num]
            
            # Obtener dimensiones de la página
            rect = page.rect
            
            # Convertir mm a puntos (1 mm = 2.83465 puntos)
            crop_top_pts = crop_top_mm * 2.83465
            crop_bottom_pts = crop_bottom_mm * 2.83465
            
            # Definir el área a conservar (recortando arriba y abajo)
            new_rect = fitz.Rect(
                rect.x0,                    # izquierda (sin cambio)
                rect.y0 + crop_top_pts,     # arriba (recortar)
                rect.x1,                    # derecha (sin cambio)
                rect.y1 - crop_bottom_pts   # abajo (recortar)
            )
            
            # Aplicar recorte
            page.set_cropbox(new_rect)
            
            # Agregar página al nuevo PDF
            pdf_out.insert_pdf(doc, from_page=page_num, to_page=page_num)
        
        # Guardar PDF recortado
        pdf_out.save(temp_pdf_path)
        pdf_out.close()
        doc.close()
        
        return temp_pdf_path
    
    except Exception as e:
        print(f"Error al recortar PDF '{ruta_pdf}': {e}")
        return ruta_pdf  # Devolver PDF original si falla

# %%
def extraer_texto_pdf(ruta_pdf, recortar_headers=True, crop_top_mm=20, crop_bottom_mm=20):
    """
    Extrae el texto de un PDF usando Apache Tika.
    Opcionalmente recorta encabezados y pies de página antes de extraer.
    
    Args:
        ruta_pdf: Ruta al archivo PDF
        recortar_headers: Si True, recorta encabezados/pies antes de extraer
        crop_top_mm: Milímetros a recortar desde arriba
        crop_bottom_mm: Milímetros a recortar desde abajo
    """
    pdf_temp = None
    try:
        # Recortar PDF si se solicita
        if recortar_headers:
            pdf_temp = recortar_pdf_headers_footers(ruta_pdf, crop_top_mm, crop_bottom_mm)
            pdf_a_procesar = pdf_temp
        else:
            pdf_a_procesar = ruta_pdf
        
        # Extraer texto con Tika
        raw = parser.from_file(pdf_a_procesar)  
        texto = raw.get("content", "").strip()
        
        # Limpiar archivo temporal
        if pdf_temp and pdf_temp != ruta_pdf:
            try:
                os.unlink(pdf_temp)
            except:
                pass
        
        return texto
    
    except Exception as e:
        print(f"Error al procesar '{ruta_pdf}': {e}")
        # Limpiar archivo temporal en caso de error
        if pdf_temp and pdf_temp != ruta_pdf:
            try:
                os.unlink(pdf_temp)
            except:
                pass
        return None

# %%
def procesar_documentos(carpeta, 
                       recortar_pdf_headers=True, 
                       crop_top_mm=20, 
                       crop_bottom_mm=20):
    """ 
    Procesa PDFs y DOCX en una carpeta y extrae los artículos.
    
    Args:
        carpeta: Ruta a la carpeta con documentos
        recortar_pdf_headers: Si True, recorta encabezados/pies de PDFs antes de extraer
        crop_top_mm: Milímetros a recortar desde arriba en PDFs
        crop_bottom_mm: Milímetros a recortar desde abajo en PDFs
    """
    todos_articulos = []

    for archivo in os.listdir(carpeta):
        ruta = os.path.join(carpeta, archivo)

        if archivo.lower().endswith(".pdf"):
            print(f"Procesando PDF: {archivo} (recortando {crop_top_mm}mm arriba, {crop_bottom_mm}mm abajo)")
            texto = extraer_texto_pdf(ruta, 
                                     recortar_headers=recortar_pdf_headers,
                                     crop_top_mm=crop_top_mm,
                                     crop_bottom_mm=crop_bottom_mm)

        elif archivo.lower().endswith((".docx", ".doc")):
            print(f"Procesando DOCX: {archivo}")
            texto = extraer_texto_docx(ruta)

        else:
            continue  # Ignorar archivos que no sean PDF o DOCX

        if not texto:
            continue  # Saltar archivos con errores o vacíos

        # Obtener nombre del archivo sin extensión
        nombre_archivo = os.path.splitext(archivo)[0]

        # FLUJO MEJORADO:
        # 1. Normalizar
        texto = normaliza_texto(texto)
        
        # 2. Separar transitorios del texto principal
        texto_principal, texto_transitorios = separar_transitorios(texto)
        
        # 3. Quitar encabezados estructurales aislados del texto principal
        texto_principal = quitar_encabezados_conservador(texto_principal)
        
        # 4. Extraer artículos del texto principal (incluye limpieza individual)
        articulos = extraer_articulos(texto_principal)
        
        for art in articulos:
            art["Archivo"] = nombre_archivo

        todos_articulos.extend(articulos)
        
        # 5. Si hay transitorios, agregarlos como un artículo especial
        if texto_transitorios:
            # Limpiar el contenido de los transitorios (igual que artículos)
            texto_transitorios_limpio = limpiar_contenido_articulo(texto_transitorios)
            
            todos_articulos.append({
                "Archivo": nombre_archivo,
                "Articulo": "TRANSITORIOS",
                "Texto": texto_transitorios_limpio
            })

    return todos_articulos

# %%
if __name__ == '__main__':
    # Procesar documentos y extraer artículos
    carpeta = "/Users/alexa/Projects/cdmx_pipeline/data/01_input/docx_leyes/"
    
    # Parámetros de recorte para PDFs (ajusta según necesites)
    # crop_top_mm: milímetros a recortar desde arriba (encabezado)
    # crop_bottom_mm: milímetros a recortar desde abajo (pie de página)
    lista_articulos = procesar_documentos(
        carpeta, 
        recortar_pdf_headers=True,  # Cambiar a False para desactivar recorte
        crop_top_mm=20,             # Ajustar según el tamaño de encabezados
        crop_bottom_mm=20           # Ajustar según el tamaño de pies de página
    )
    
    # Crear DataFrame con columnas básicas
    df = pd.DataFrame(lista_articulos, columns=["Archivo", "Articulo", "Texto"])
    
    print(f"\nTotal de artículos extraídos: {len(df)}")
    print(f"Total de documentos únicos: {df['Archivo'].nunique()}")
    print("\nPrimeros 5 artículos:")
    print(df.head())
    
    # Verificar si hay artículos con texto muy corto (posible pérdida de contenido)
    articulos_cortos = df[df['Texto'].str.len() < 20]
    print(f"\nArtículos con texto < 20 caracteres: {len(articulos_cortos)}")
    if len(articulos_cortos) > 0:
        print("Ejemplos:")
        print(articulos_cortos.head(10))

    output_path = "/Users/alexa/Projects/cdmx_pipeline/data/01_input/extracted_articles.xlsx"
    df.to_excel(output_path, index=False)
    print(f"\nArchivo guardado en: {output_path}")
# Out:
# Procesando DOCX: RGTO_DE_LA_LEY_DE_CENTROS_PENITENCIARIOS_DE_LA_CDMX.docx
# Procesando DOCX: REGLAMENTODEINTEGRACIONFUNCIONAMIENTOYSESIONESDELOSCONSEJOSDISTRITALESDELINSTITUTOELECTORALDELDISTRITOFEDERAL3.docx
# Procesando DOCX: RGTO_INTERIOR_DE_LA_UNIVERSIDAD_DE_LA_POLICIA_CDMX_2.5.docx
# Procesando DOCX: REGLAMENTO_LEY_PROTECCION20_A_LA_SALUD_DE_LOS_NO_FUMADORES_EN_EL_DF_3.docx
# Procesando DOCX: LEY_BANCO_ADN_PARA_USO_FORENSE_DE_LA_CIUDAD_DE_MEXICO_2.1.docx
# Procesando DOCX: LEY_PROCESAL_ELECTORAL_DE_LA_CDMX_5.3.docx
# Procesando DOCX: LEY_DE_MEJORA_REGULATORIA_PARA_LA_CIUDAD_DE_MEXICO_3.4.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_EJECUCION_DE_SANCIONES_PENALES_Y_REINSERCION_SOCIAL_PARA_EL_DISTRITO_FEDERAL_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: RGTO_LEY_DE_GESTION_INTEGRAL_DE_RIESGOS_Y_PROTECCION_CIVIL_5.docx
# Procesando DOCX: LEY_PARA_LA_PREV_Y_TRAT_DE_LA_OBESIDAD_CDMX_3.docx
# Procesando DOCX: LEY_DE_RESPONSABILIDADES_ADMINISTRATIVAS_DE_LA_CDMX_3.1.docx
# Procesando DOCX: LEY_20ORG_DEL_INST_DE_PLANEACION_DEMOCRATICA20_Y_PROSPECTIVA_DE_LA_CDMX_3.2.docx
# Procesando DOCX: RGTO_LEY_DE_PROTECCION_Y_FOMENTO_AL_EMPLEO_PARA_EL_DISTRITO_FEDERAL_2.docx
# Procesando DOCX: RGTO_DE_LA_LEY_DE_SEGURIDAD_PRIVADA_PARA_EL_DF.docx
# Procesando DOCX: LEY_DE_FILMACIONES_DE_LA_CIUDAD_DE_MEXICO_3.1.docx
# Procesando DOCX: LEY_QUE_CREA_ELcONSEJO_PARA_LA_PREV_Y_ATN_INT_DEL_VIH_SIDA_DEL_DF_1.1.docx
# Procesando DOCX: LEY_DE_RESPONSABILIDAD_AMBIENTAL_DE_LA_CDMX_1.docx
# Procesando DOCX: LEY_DE_GESTION_INTEGRAL_DE_RIESGOS_Y_PROTECCION_CIVIL_DE_LA_CDMX_4.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_FOMENTO_CULTURAL_DEL_DISTRITO_FEDERAL_5.1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: RGTO_LEY_DE_RESPONSABILIDAD_PATRIMONIAL_DEL_DISTRITO_FEDERAL_2.docx
# Procesando DOCX: LEY_DE_LA_SALA_CONSTITUCIONAL_DEL_PODER_JUDICIAL_DE_LA_CIUDAD_DE_MEXICO_2.1.docx
# Procesando DOCX: RGTO_LEY_PARA_PREV_Y_ERR_TRATA_DE_PERS_ABUSO_SEXUAL_Y_LA_EXPL_SEX_COM_INFANTIL_2.docx
# Procesando DOCX: LEY_DEL_NOTARIADO_PARA_LA_CIUDAD_DE_MEXICO_1.3.docx
# Procesando DOCX: LEY_QUE_EXTINGUE_LA_PRETENSION_PUNITIVA_MARCHAS_1.1.docx
# Procesando DOCX: LEY_DE_ADQUISICIONES_PARA_EL_DISTRITO_FEDERAL_2.1.docx
# Procesando DOCX: RGTO_LEY_PROM_DE_LA_CONVIV_LIBRE_DE_VIOL_EN_EL_ENT_ESC_DEL_DF_2.docx
# Procesando DOCX: Ley_Org_TJACDMX_2.1.docx
# Procesando DOCX: LEY_PARA_EL_DESARROLLO_DEL_DF-COMO-CIUDAD-DIGITAL_Y_DEL_CONOCIMIENTO_2.1.docx
# Procesando DOCX: LEY_DE_MEJORAMIENTO_BARRIAL_Y_COMUNITARIO_DEL_DF_2.3.docx
# Procesando DOCX: RGTO_INTERIOR_DEL_PODER_EJECUTIVO_Y_DE_LA_ADMINISTRACION_PUBLICA_DE_LA_CIUDAD_DE_MEXICO_40.1.docx
# Procesando DOCX: LEY_ORGANICA_DE_LA_PAOT_DE_LA_CDMX_3.1.docx
# Procesando PDF: REGLAMENTO_PARA_EL_USO_Y_PRESERVACION_DEL_PARQUE_DE_LAS_AGUILAS_2.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_REC_DERECHOS_PERSONAS_MAYORES_Y_DEL_SISTEMA_INT_PARA_SU_ATN_DE_LA_CDMX_5.docx
# Procesando DOCX: LEY_DE_BIBLIOTECAS_20DE20_LA20_CIUDAD20_DE20_MEXICO_3.4.docx
# Procesando DOCX: LEY_PARA_PREV_LA_VIOLENCIA_EN_LOS_ESP_DEPORT_DEL_DF_2.docx
# Procesando DOCX: LEY_ORGANICA_DEL_PODER_JUDICIAL_DE_LA_CDMX_3.1.docx
# Procesando DOCX: LEY_ORGANICA_DEL_CENTRO_DE_CONCILIACION_LABORAL_DE_LA_CIUDAD_DE20_MEXICO_1.4.docx
# Procesando DOCX: RGTO_INT_DE_LA_COM_DE_DER_HUM_2.5.docx
# Procesando DOCX: RGTO_VEHICULOS_AMBULANCIA_CDMX_1.docx
# Procesando DOCX: LEY_AMBIENTAL_DE_LA_CDMX.docx
# Procesando DOCX: CODIGO_CIVIL_PARA_EL_DF_15.2.docx
# Procesando DOCX: LEY_DE_SOCIEDAD_DE_CONVIVENCIA_PARA_LA_CDMX_2.1.docx
# Procesando DOCX: RGTO_DE_LA_COM_TEC_DE_BOX_Y_EL_DESARROLLO_DE_ESP_PUB_DE_BOXEO_EN_LA_CDMX.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_ASISTENCIA_Y_PREVENCION_DE_LA_VIOLENCIA_INTRAFAMILIAR_DEL_DISTRITO_FEDERAL.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_PARALA_ATENCION_INTEGRAL_DELAS_PERSONAS_CON_SINDROME_DE_DOWN_CDMX_3.docx
# Procesando DOCX: LEY_ORGANICA_DE_LA_FISCALIA_GENERAL_DE_JUSTICIA_DE_LA_CIUDAD_DE_MEXICO_7.docx
# Procesando DOCX: RGTO_LEY_DERE_DE_NINAS_NINOS_Y_ADOLESCENTES_DE_LA_CIUDAD_DE_MEXICO_1.docx
# Procesando DOCX: REGLAMENTO_DE_LOS_CENTROS_DE_DESARROLLO_INFANTIL_DEL_TRIBUNAL_SUPERIOR_DE_JUSTICIA_DEL_DISTRITO_FEDERAL_2.docx
# Procesando DOCX: LEY_DE_FOMENTO_COOPERATIVO_PARA_EL_DF_4.docx
# Procesando DOCX: LEY_DE_EDUCACION_FISICA_Y_DEPORTE_DEL_DF_9.1.docx
# Procesando DOCX: LEY_DE_RESP_20SOC_20MERCANTIL_DE20LA20CIUDAD20DE20MEXICO_2.4.docx
# Procesando DOCX: RGTO_LEY_DE_ACC_DE_LAS_MUJERES_A_UNA_VIDA_LIBRE_DE_VIOLENCIA_2.docx
# Procesando DOCX: LEY_REGISTRAL_PARA_LA_CDMX_2.3.docx
# Procesando DOCX: LEY_DE_ASISTENCIA_E_INTEGRA_SOCIAL_DEL_DF_2.1.docx
# Procesando DOCX: LEY_DE_COORDINACION_METROPOLITANA_DE_LA_CIUDAD_DE_MEXICO_3.1.docx
# Procesando DOCX: RGTO_COTECIAD_INMUJERES_DF2.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_ESTABLECIMIENTOS_MERCANTILES_PARA_LA_CIUDAD_DE_MEXICO_2.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DEL_FONDO_DE_APOYO_A_LA_PROCURA_DE_JUST_DF_3.1.docx
# Procesando DOCX: RGTO_DELA_PROCURADURIA_DELA_DEFENSA_DEL_TRABAJO_DEL_DF_2.docx
# Procesando DOCX: LEY_DE_SEGURIDAD_PRIVADA_PARA_EL_DF_2.1.docx
# Procesando DOCX: LEY_DE_ESPACIOS_CULTURALES_INDEPENDIENTES_DE_LA_CDMX_3.docx
# Procesando DOCX: RGTO_LEY_PARA_LA_PROT_ATN_Y_ASIST_A_LAS_VICT_DE_DEL_EN_MAT_DE_TRAT_DE_PERS_DEL_DF_2.docx
# Procesando DOCX: RGTO_INT_OFNA_INFO_PUB_CAJA_DE_PREV_DE_LA_POLICIA_PREV_DEL_DF_2.docx
# Procesando DOCX: LEY_DEL_PROGRAMA_DE_DERECHOS_HUMANOS_DEL_DF_2.docx
# Procesando DOCX: LEY_DE_EXTINCION_DE_DOMINIO_PARA_LA_CDMX_1.1.docx
# Procesando DOCX: RGTO_CONGRESO_CDMX_3.3.docx
# Procesando DOCX: REGLAMENTODEOPERACIONDELCOMITEDETRANSPARENCIADELTRIBUNALELECTORALDELDISTRITOFEDERAL3.1.docx
# Procesando DOCX: LEY_DE_COMEDORES_SOCIALES_DE_LA_CDMX_4.docx
# Procesando DOCX: LEY_DE_PARTICIPACION_CIUDADANA_DE_LA_CDMX_4.2.docx
# Procesando DOCX: LEY_DE_CUNAS_DE_LA_CDMX_3.docx
# Procesando DOCX: LEY_DE_CULTURA_CIVICA_DE_LA_CIUDAD_DE_MEXICO_2.7.docx
# Procesando DOCX: RGTO_INT_DE_LA_SECRETARIA_DE_SEGURIDAD_CIUDADANA_DE_LA_CIUDAD_DE_MEXICO_4.docx
# Procesando PDF: REGLAMENTO_DEL_MECANISMO_DE_SEGUIMIENTO_Y_EVALUACION_DEL_PROGRAMA_DE_DERECHOS_HUMANOS_DEL_DISTRITO_FEDERAL20_1.1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DE_PROPIEDAD_EN_CONDOMINIO_DE_INMUEBLES_PARA_EL_DF_4.docx
# Procesando DOCX: LEY_REGULA_FUNCIONAMIENTO_DE_LOS_CACI_DEL_DF_1.3.docx
# Procesando DOCX: LEY_DERECHOS_NINAS_NINOS_ADOLESCENTES_CDMX_7.2.docx
# Procesando DOCX: LEY_CONSTITUCIONAL_DE_DERECHOS_HUMANOS_Y_SUS_GARANTIAS_DE_LA_CIUDAD_DE_MEXICO_2.1.docx
# Procesando DOCX: CODIGO_DE_INSTITUCIONES_Y_PROC_ELECTORALES_CDMX_6.docx
# Procesando DOCX: LEY_DE_FISCALIZACION_SUPERIOR_DE_LA_CDMX_2.docx
# Procesando PDF: REGLAMENTO_PARA_TERMINALES_INTERIORES_DE_CARGA_2.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DE_LOS_DERECHOS_DE_LAS_PERSONAS_MAYORES_DE_LA_CDMX_3.docx
# Procesando DOCX: LEY_ORGANICA_DEL_PODER_EJECUTIVO_Y_DE_LA_ADMINISTRACION_PUBLICA_DE_LA_CDMX_7.1.docx
# Procesando DOCX: LEY_DE_ACCESO_DE_LAS_MUJERES_A_UNA_VIDA_LIBRE_DE_VIOLENCIA_DE_LA_CDMX_12.3.docx
# Procesando DOCX: LEY_DEL_TERRITORIO_DE_LA_CIUDAD_DE_MEXICO_1.1.docx
# Procesando DOCX: RTO_ECONOMIA_CIRCULAR_CDMX.docx
# Procesando DOCX: LEY_DE_INGRESOS_2025.docx
# Procesando DOCX: LEY_DE_FOMENTO_CULTURAL_DE_LA_CDMX_5.1.docx
# Procesando DOCX: CODIGO_PENAL_PARA_EL_DF_12.3.2.docx
# Procesando DOCX: LEY_DE_JUSTICIA_PARA_ADOLESCENTES_PARA_EL_DF_2.1.docx
# Procesando DOCX: LEY_DE_DESARROLLO_URBANO_DEL_DF_5.1.docx
# Procesando DOCX: REGLAMENTO_TAURINO_PARA_EL_DISTRITO_FEDERAL_2.docx
# Procesando DOCX: RGTO_INT_CONS_PARA_LA_PREV_Y_ATN_INT_DE_LA_OBESIDAD_2.docx
# Procesando DOCX: RGTO_DE_CONSTRUCCIONES_DEL_DISTRITO_FEDERAL_8.1.docx
# Procesando DOCX: REG_INSP_20LOC_DEL_TRAB_D_F3.docx
# Procesando DOCX: Reglamento_de_la_Policia_Preventiva_del_Distrito_Federal_1.docx
# Procesando DOCX: LEY_DEL_REGIMEN_PATRIMONIAL_Y_DEL_SERVICIO_PUBLICO_8.docx
# Procesando DOCX: LEY_DE_LOS_DERECHOS_CULTURALES_DE_LOS_HABITANTES_Y_VISITANTES_DE_LA_CIUDAD_DE_MEXICO_2.docx
# Procesando DOCX: Ley_Organica_del_Consejo_Economico_Social_y_Ambiental_CDMX_5.4.docx
# Procesando DOCX: LEY_PARALA_PREV_TRAT_Y_CONTROL_DE_LA_DIABETES_EN_EL_DF_2.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_CULTURA_CIVICA_DE_LA_CDMX.pdf (recortando 20mm arriba, 20mm abajo)
# Error al procesar '/Users/alexa/Projects/cdmx_pipeline/data/01_input/docx_leyes/REGLAMENTO_DE_LA_LEY_DE_CULTURA_CIVICA_DE_LA_CDMX.pdf': HTTPConnectionPool(host='localhost', port=9998): Read timed out. (read timeout=60)
# Procesando PDF: REGLAMENTO_PARA_EL_ORDENAMIENTO_DEL_PAISAJE_URBANO_DEL_DF_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DE_HUERTOS_URBANOS_DE_LA_CIUDAD_DE_MEXICO_3.2.docx
# Procesando DOCX: LEY_DERECHO_ALIMENTARIO_A_MADRES_SOLAS_DE_ESCASOS_1.2.docx
# Procesando PDF: REGLAMENTO_INTERNO_DE_LA_COMISION_DE_LIMITES_DEL_DISTRITO_FEDERAL.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DE_ALBERG_PUB_PRIV_NINAS_Y_NINOS_DF_2.3.docx
# Procesando DOCX: REGLAMENTO_DE_LA_LEY_QUE_ESTABLECE_EL_DERECHO_AL_ACCESO_GRATUITO_A_LOS_SERVICIOS_MEDICOS_Y_MEDICAMENTOS_A_LAS_PERSONAS_RESIDENTES_EN_EL_DISTRITO_FEDER.docx
# Procesando DOCX: LEY_PROC_REMOCION_DE_SERV_PUBLICOS_NOMB_POR_LA_ALDF_Y_TIT_ORG_POL_ADMIN_2.1.docx
# Procesando DOCX: RGTO_INT_CONS_CIUD_DE_SEG_PUB_Y_PROC_DE_JUSTICIA_DEL_DF_2.docx
# Procesando DOCX: LEY_DE_LA_PROCURADURIA_SOCIAL_DEL_DF_3.1.docx
# Procesando DOCX: LEY_DE_EJECUCION_DE_SANCIONES_PENALES_Y_REINSERCION_SOCIAL_PARA_EL_DF_2.docx
# Procesando DOCX: LEY_DE_VIVIENDA_PARA_LA_CDMX_4.3.docx
# Procesando DOCX: RGTO_SERV_DE_TRANSPORTE_ESCOLAR_Y_DE_PERSONAL_PARA_EL_DF_2.docx
# Procesando DOCX: REG_DE_LEY_DE_MOVILIDAD_DE_LA_CDMX_4.5.docx
# Procesando DOCX: RGTO_LEY_DEL_H_CUERPO_DE_BOMBEROS_DEL_DF_3.docx
# Procesando DOCX: LEY_DE_ARCHIVOS_DE_LA_CDMX_2.1.docx
# Procesando DOCX: REGLAMENTO_DEL_INSTITUTO_DE_FORMACION_PROFESIONAL_PGJ_DF2.docx
# Procesando DOCX: LEY_DE_PREVENCION_SOCIAL_DEL_DELITO_Y_LA_VIOLENCIA_PARA_EL_DF_2.2.docx
# Procesando DOCX: REGLAMENTO_INTERIOR_DEL_TRIBUNAL_ELECTORAL_DE_LA_CIUDAD_DE_MEXICO_1.docx
# Procesando DOCX: REGLAMENTO_DEL_REGISTRO_CIVIL_DE_LA_CDMX_1.1.docx
# Procesando PDF: RGTO_INTERIOR_DE_LA_COMISION_DE_LUCHA_LIBRE_PROFESIONAL_DEL_DISTRITO_FEDERAL_4.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: RGTO_EN_MAT_DE_TRANSP_ACC_A_INF_PUB_Y_PROT_DATOS_PERS_DEL_TEDF_1.docx
# Procesando DOCX: RGTO_LEY_CELEBRACIOION_ESPECT_PUB_DEL_DF_EN_MAT_DE_ESPECT_MASIV_Y_DEP_4.docx
# Procesando DOCX: LEY_DE_LA_INST_DESC_DEL_SERV_PUB_DEL_DF_SERV_DE_TRANSP_ELECTRICOS_3.1.docx
# Procesando DOCX: RGTO_DE_LOS_ORGANOS_CJH_SCC_CDMX.docx
# Procesando DOCX: CONSTITUCION_POLITICA_DE_LA_CDMX_14.2.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_LA_CAJA_DE_PREVISION_DE_LA_POLICIA_PREVENTIVA_DEL_DISTRITO_FEDERAL_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DEL_INST_PARA_LA_SEG_DE_LAS_CONSTRUCCIONES_DEL_DF_3.1.docx
# Procesando DOCX: REGLAMENTODESESIONESDELCONSEJOGENERALYCOMISIONESDELINSTITUTOELECTORALDELDISTRITOFEDERAL5.docx
# Procesando DOCX: LEY_DE_IGUALDAD_SUSTANTIVA_ENTRE_M_Y_H_EN_LA_CDMX_3.8.docx
# Procesando DOCX: LEY_DE_PLANEACION_DEMOGRAFICA_Y_ESTADISTICA_PARA_LA_POBLACION_DEL_DF_2.1.docx
# Procesando DOCX: LEY_PROT_INT_PERSONAS_DDH_Y_PERIODISTAS_DF_3.1.docx
# Procesando DOCX: LEY_ORG_SALA_CONSTITUCIONAL_DEL_PJCDMX_2.1.docx
# Procesando DOCX: LEY_DE_PROTECCION_DE_DATOS_PERSONALES_EN_POSESION_DE_SUJETOS_OBLIGADOS_DE_LA_CDMX_4.docx
# Procesando DOCX: RMODDESARROLLOURBANO2.docx
# Procesando PDF: REGLAMENTO_PARA_LOS_TRABAJADORES_NO_ASALARIADOS_DEL_DISTRITO_FEDERAL_2.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DE_SOCIEDADES_MUTUALISTAS_DE_LA_CDMX_3.1.docx
# Procesando DOCX: LEY_DE_MITIGACION_Y_ADAPTACION_AL_CAMBIO_CLIMATICO_Y_DESARROLLO_SUSTENTABLE_DE_LA_CDMX_6.2.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_BIBLIOTECAS_DEL_DISTRITO_FEDERAL.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_ORGANICA_DE_ALCALDIAS_DE_LA_CDMX_6.2.docx
# Procesando DOCX: REGLAMENTO_DE_IMPACTO_AMBIENTAL_Y_RIESGO3.docx
# Procesando DOCX: LEY_DE_ATEN_PRIO_P_LAS_PERSONAS_CON_DISCA_Y_EN_SITUACION_DE_VULNE_EN_LA_CDMX_3.docx
# Procesando DOCX: RGTO_DE_LA_LEY_DE_DESA_URBANO_DEL_DF_4.2.docx
# Procesando DOCX: LEY_PARA_PREV_ELIM_Y_SANC_LA_DESAP_FORZADA_Y_LA_DESAP_POR_PART_EN_LA_CDMX_2.docx
# Procesando DOCX: LEY_DE_PROTECCION_Y_FOMENTO_AL_EMPLEO_PARA_LA_CDMX_1.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_INTERCULTURALIDAD_ATENCION_A_MIGRANTES_Y_MOVILIDAD_HUMANA_EN_EL_DISTRITO_FEDERAL.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_TRANSPARENCIA_Y_ACCESO_DE_LA_ADMINISTRACION_PUBLICA_DE_LA_ADMINISTRACION_PUBLICA_DEL_DF_4.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: REG_CONSEJO_DE_PUB_EXT_DF3.docx
# Procesando DOCX: LEY_DELA_DEFENSORIA_PUBLICA_DEL_DF_5.1.docx
# Procesando DOCX: LEY_DEL_SERVICIO_PUBLICO_DE_CARRERA_DE_LA_ADM_PUB_DE_LA_CDMX_2.3.docx
# Procesando DOCX: LEY_DE_CENTROS_PENITENCIARIOS_DE_LA_CDMX_2.1.docx
# Procesando DOCX: LEY_DE_PRESTACION_DE_SERVICIOS_INMOBILIARIOS_DEL_DF_2.1.docx
# Procesando DOCX: REGLAMENTODELALEYDEADQUISICIONESPARAELDISTRITOFEDERALII2.docx
# Procesando DOCX: LEY_QUE_REGULA_EL_USO_DELA_TECNOLOGIA_PARA_LA_SEGURIDAD_PUBLICA_DEL_DF_2.3.docx
# Procesando DOCX: LEY_DE_RESIDUOS_SOLIDOS_DEL_DF_7.docx
# Procesando DOCX: RGTO_INT_DEL_TRIB_JUST_ADM_DE_LA_CDMX3.docx
# Procesando DOCX: RGTO_DE_LEY_ATENCION_INTEGRAL_P_DESA_DE_NINAS_Y_NINOS_EN_PRIMERA_INFANCIA_EN_EL_DF3.1.docx
# Procesando DOCX: LEY_ACCESO_GRATUITO_INTERNET_CDMX_1.docx
# Procesando DOCX: LEY_DE_MOVILIDAD_DE_LA_CDMX_3.2.docx
# Procesando PDF: REGLAMENTO_PARA_EL_USO_Y_PRESERVACION_DEL_BOSQUE_DE_CHAPULTEPEC_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: rgto_de_la_ley_de_huertos_urbanos_cdmx.docx
# Procesando PDF: REGLAMENTO_INTERNO_DEL_INSTITUTO_DE_LAS_MUJERES_DEL_DISTRITO_FEDERAL_2.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: RGTO_INTERIOR_INE_CDMX_1.docx
# Procesando DOCX: LEY_DE_AUDITORIA_Y_CONTROL_INTERNO_DE_LA_ADMON_PUBLICA_DE_LA_CDMX_3.1.docx
# Procesando DOCX: LEY_DE_SEGURIDAD_ALIMENTARIA_Y_NUTRICIONAL_PARA_EL_DF_2.1.docx
# Procesando DOCX: REGLAMENTO_INTERIOR_DEL_INSTITUTO_DE_LA_DIABETES_2.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_EDUCACION_FISICA_Y_DEPORTE_DEL_DISTRITO_FEDERAL_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_FOMENTO_A_LAS_ACTIVIDADES_DE_DESARROLLO_SOCIAL_DE_LAS_ORGANIZACIONES_CIVILES_PARA_EL_DISTRITO_FEDERAL.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DE_UNIDAD_DE_CUENTA_DE_LA_CDMX_2.3.docx
# Procesando DOCX: RGTO_INTERNO_DEL_CENTRO_DE_JUST_ALTERNA_DEL_TSJ_DE_LA_CDMX3.docx
# Procesando DOCX: RGTO_LEY_DE_MITI_Y_ADAPT_AL_CAMBIO_CLIM_Y_DESARR_SUST_DF_3.docx
# Procesando DOCX: LEY_PARA_LA_RECONSTRUCCION_INTEGRAL_DE_LA_CIUDAD_DE_MEXICO_6.1_2.docx
# Procesando DOCX: REGLAMENTO_DE_TRANSITO_DE_LA_CIUDAD_DE_MEXICO_6.1.docx
# Procesando DOCX: RGTO_DE_LA_LEY_DE_LA_PROCURADURIA_SOCIAL_DEL_DISTRITO_FEDERAL_2.docx
# Procesando DOCX: LEY_DE_ALBERGUES_PRIVADOS_PARA_PERSONAS_ADULTAS_MAYORES_DEL_DF_3.docx
# Procesando PDF: REGLAMENTO_PARA_EL_GOBIERNO_INTERIOR_DE_LA_ASAMBLEA_LEGISLATIVA_DEL_DISTRITO_FEDERAL_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: REGLAMENTO_PARA_LA_OPERACION_DE_VIDEOJUEGOS_DEL_DF_3.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_DESARROLLO_AGROPECUARIO_RURAL_Y_SUSTENTABLE_DEL_DISTRITO_FEDERAL.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: Ley_para_la_Celebracion_de_Espectaculos_Publicos_de_la_CDMX_3.4.docx
# Procesando DOCX: LEY_DE_PROTECCION_A_LA_SALUD_DE_LOS_NO_FUMADORES_2.2.docx
# Procesando DOCX: RGTO_LEY_QUE_ESTABLECE_EL_DERECHO_SALUD_BUCODENTAL_2.docx
# Procesando DOCX: RGTO_DE_LA_COMISION_COORDINADORA_DEL_SISTEMA_GENERAL_DE_BIENESTAR_SOCIAL.docx
# Procesando PDF: REGLAMENTOQUEESTABLECEELDERECHOACONTARCONUNABECAPARALOSJOVENESRESIDENTESENELDISTRITOFEDERAL.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: CODIGO_DE_ETICA_DE_LA_AP_DE_LA_CIUDAD_DE_MEXICO_2.1.docx
# Procesando DOCX: RGTO_LEY_JUSTICIA_ADOLECENTES_EN_MAT_DE_EJEC_1.docx
# Procesando DOCX: LEY_DE_FOMENTO_DE_PROCESOS_PRODUCTIVOS_EFICIENTES_PARA_EL_DF_4.1.docx
# Procesando DOCX: Reglamento_Interior_de_la_AuditorIa_Superior_de_la_Ciudad_de_Mexico_1.docx
# Procesando DOCX: LEY_DE_MEMORIA_DE_LA_CDMX.docx
# Procesando PDF: LEYDPROTECCIONDEDATOSPERSONALESPARAELDISTRITOFEDERAL.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DEL_SISTEMA_DE_SEGURIDAD_CIUDADANA_DE_LA_CDMX_10.docx
# Procesando DOCX: Ley_para_la_Donacion_Altruista_de_Alimentos_2.4.docx
# Procesando DOCX: LEY_SECRETO_PROF_Y_CLAUS_DE_CONCIEN_EJERCICIO_PERIODISTICO_DE_LA_CDMX_2.1.docx
# Procesando DOCX: RGTO_INT_DEL_COM_DE_INF_ESTAD_Y_GEO_DE_LA_CDMX_2.docx
# Procesando DOCX: LEY_DE_LA_UNIVERSIDAD_AUTONOMA_DE_LA_CDMX_2.2.docx
# Procesando DOCX: LEY_DE_BEBE_SEGURO_DE_LA_CDMX_6.docx
# Procesando DOCX: LEY_DE_INFRAESTRUCTURA_FISICA_EDUCATIVA_DEL_DF_2.3.docx
# Procesando DOCX: RGTO_LEY_QUE_REG_EL_USO_DE_LA_FUER_DE_LOS_CUERP_DE_SEG_PUB_DEL_DF.docx
# Procesando DOCX: LEY_PARA_LA_ATENCION_PERSONAS_ESPECTRO_AUTISTA_3.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_P_G_J_DF.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DERECHO_AL_ACCESO_A_LOS_SERV_MEDICOS_Y_MEDICAMENTOS_RESIDENTES_DF_1.1.docx
# Procesando DOCX: REGTO_DE_VERIFICACION_ADMIN_DF4.docx
# Procesando DOCX: LEY_DE_FOMENTO_A_LAS_ACTI_DE_DESARROLLO_SOCIAL_DE_LAS_ORNG_CIVILES_PARA_EL_DF_2.3.docx
# Procesando DOCX: LEY_DE_SALUD_MENTAL_DEL_DF_2.1.docx
# Procesando DOCX: REGLAMENTO_DE_LA_LEY_DE_VICTIMAS_PARA20_LA_CDMX3.docx
# Procesando DOCX: LEY_AUST_TRANSP_EN_REMUN_PREST_Y_EJERC_DE_REC_DE_LA_CIUDAD_DE_MEXICO_5.8.docx
# Procesando DOCX: LEY_PARA_LA_ATN_DELITOS_TRATA_DE_PERSONAS_DE_LA_CDMX_4.docx
# Procesando DOCX: LEY_DE_LOS_DERECHOS_DE_LAS_PERSONAS_JOVENES_EN_LA_CIUDAD_DE_MEXICO_3.3.docx
# Procesando DOCX: LEY_DE_PROTECCION_Y_BIENESTAR_DE_LOS_ANIMALES_DE_LA_CDMX_1.1.4.docx
# Procesando DOCX: LEY_PARA_LA_INT_AL_DESA_DE_LAS_PERS_CON_DISCAPACIDAD_DEL_DF_6.4.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_FILMACIONES_DEL_DISTRITO_FEDERAL.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando PDF: REGLAMENTO_PARA_EL_USO_Y_PRESERVACION_DEL_PARQUE_CULTURAL_Y_RECREATIVO_DESIERTO_DE_LOS_LEONES_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: REGLAMENTO_DEL_SERVICIO_PROFESIONAL_DE_CARRERA_DE_LA_POLICIA_DE_PROXIMIDAD_DE_LA_CIUDAD_DE_MEXICO_3.docx
# Procesando DOCX: Ley_para_el_Desarrollo_de_la_Competitividad_de_la_MIPYMES_para_DF_3.3.docx
# Procesando PDF: REGLAMENTO_QUE_ESTABLECE_EL_PROCEDIMIENTO_PARA_LA_CONCLUSION_DE_LA_CARRERA_POLICIAL_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DEL_INSTI_DE_ESTUDIOS_CIENTIFICOS_PARA_LA_PREV_DEL_DELITO_EN_LA_CDMX_2.1.docx
# Procesando DOCX: REGLAMENTO_DE_LA_LEY_DE_AUSTERIDAD_TRANSPARENCIA_EN_REMUNERACIONES_PRESTACIONES_Y_EJERCICIO_DE_RECURSOS_DE_LA_CIUDAD_DE_MEXICO_4.4.docx
# Procesando DOCX: RGTO_DE_LA_LEY_PARA_LA_INTEGRACION_AL_DESARROLLO_DE_LAS_PERSONAS_CON_DISCAPACIDAD_CDMX_2.4.docx
# Procesando DOCX: RTO_LEY_ESP_CULTURALES_IND_CDMX.docx
# Procesando DOCX: LEY_DEL_DERECHO_AL_BIENESTAR.docx
# Procesando DOCX: RGTO_REGIST_DE_ORG_CIUD_ANTE_EL_IECDMX3.docx
# Procesando DOCX: LEY_DE_FOMENTO_PARA_LA_LECTURA_Y_EL_LIBRO_DE_LA_CIUDAD_DE_MEXICO_6.6.docx
# Procesando DOCX: RTO_CSJO_DUS_DF_1.docx
# Procesando DOCX: LEY_DE_OBRAS_PUBLICAS_DEL_DF_3.docx
# Procesando DOCX: RGTO_LEY_PARA_LA_RET_POR_LA_PROT_DE_LOS_SERV_AMB_DEL_SUELO_DE_CONSERV_DEL_DF_3.docx
# Procesando DOCX: LEY_PARA_LA_PREVENCION_DE_ENFERMEDADES_BUCODENTALES_2.docx
# Procesando DOCX: RGTO_REGULA_PERDIDA_REGISTRO_ORG_POLITICAS_2.docx
# Procesando DOCX: CODIGO_FISCAL_DE_LA_CDMX_25.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_FIRMA_ELECTRONICA_PARA_EL_DISTRITO_FEDERAL_EN_ACTOS_PROCEDIMIENTOS_Y_TRAMITES_A_CARGO_DE_LA_ADMINISTRACION_PUBLICA_DEL_DISTRIT.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DE_INTERCULTURALIDAD_ATENCION_A_MIGRANTES_Y_MOVILIDAD_HUMANA_EN_EL_DF_2.1.docx
# Procesando DOCX: PRESUPUESTO_DE_EGRESOS_2024201.1.docx
# Procesando DOCX: RGTO_CONSEJO_CONSULT_CIUD_INMUJERESDF3.docx
# Procesando DOCX: LEY_DEL_INSTIT_DE_20VERIFICACION_ADMITVA_DE_LA_CIUDAD_DE_MEXICO_4.docx
# Procesando DOCX: RGTO_TRAM_Y_SUST_DE_QUEJ_Y_PROC_DE_INVEST_DEL_IECDMX3.docx
# Procesando DOCX: RTO_FISCALIZACION_INSTITUTO_ELECTORAL_CDMX.docx
# Procesando DOCX: LEY_DE_DECLARACION_ESP_DE20AUSENCIA_PARA_PERS_DESAPARECIDAS_EN_LA_CDMX_3.docx
# Procesando DOCX: LEY_DE_PUBLICIDAD_EXTERIOR_DE_LA_CDMX_2.1.docx
# Procesando DOCX: RGTO_LEY_GENERAL_EQUILIBRIO_ECOLOGICO_Y_PROT_AL_AMBIENTE_1.docx
# Procesando DOCX: LEY_ATN_Y_APO_A_VICT_DEIN_SECUESTRO_2.1.docx
# Procesando DOCX: LEY_PENSION_PARA_EL_BIENESTAR_PERSONAS_MAYORES_2.1.docx
# Procesando DOCX: REGLAMENTO_DE_LA_LEY_REGISTRAL_PARA_LA_CIUDAD_DE_MEXICO_2.docx
# Procesando DOCX: LEY_DEL_SISTEMA_ANTICORRUPCION_DE_LA_CIUDAD_DE_MEXICO_4.1.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_OBRAS_PUBLICAS_DEL_D.F_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: RGTO_CDHDF_EN20MAT_DE_TRANSP_Y_ACC_A_LA_INFORMACION_PUBLICA2.docx
# Procesando DOCX: LEY_DEL_SISTEMA_DE_PLANEACION_DEL_DESARROLLO_DE_LA_CDMX_2.6.docx
# Procesando DOCX: LEY_DE_ESTABLECIMIENTOS_MERCANTILES_PARA_LA_CDMX_5.3.docx
# Procesando DOCX: LEY_DEL_FONDO_DE_APOYO_A_LA_ADM_DE_JUSTICIA_EN_EL_DF_2.6.docx
# Procesando DOCX: LEY_DE_INSTITUCIONES_DE_ASISTENCIA_PRIVADA_PARA_EL_DF_3.1.docx
# Procesando PDF: REGLAMENTODELALEYDEFOMENTOCOOPERATIVOPARAELDISTRITOFEDERAL.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DE_TURISMO_DE_LA_CIUDAD_DE_MEXICO_1.1.1.docx
# Procesando DOCX: LEY_DE_VOLUNTAD_ANTICIPADA_PARA_EL_DF_2.1.docx
# Procesando DOCX: REGLAMENTO_DE_LA_LEY_DEL_NOTARIADO_EN_LA_CIUDAD_DE_MEXICO_1.docx
# Procesando DOCX: RGTO_INST_ELECT_DE_LA_CDMX_EN_MAT_DE_TRANSP_ACC_INF_PUB_Y_R_C3.docx
# Procesando PDF: REGLAMENTO_DE_LA_LEY_DE_LA_DEFENSORIA_DE_OFICIO_DEL_FUERO_COMUN_EN_EL_DISTRITO_FEDERAL_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: Ley_Organica_de_la_CDHCDMX_1.3.docx
# Procesando PDF: REGLAMENTO_INTERIOR_DE_LA_COMISION_DE_SEGUIMIENTO_Y_EVALUACION_DEL_PACTO_PARA_LA_ESTABILIDAD_LA_COMPETITIVIDAD_Y_EL_EMPLEO_EN_EL_DISTRITO_FEDERAL_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: RGTO_DE_LA_LEY_DE_SALUD_DEL_DISTRITO_FEDERAL_3.docx
# Procesando DOCX: RGTO_FUN_INT_D_ORG_REPRE_PREV_EN_LA_LEY_D_PART_CIUD3.docx
# Procesando DOCX: LEY_DEL_HEROICO_CUERPO_DE_BOMBEROS_DEL_DF_2.3.docx
# Procesando DOCX: LEY_DE_TRANSPARENCIA_ACCESO_A_LA_INFORMACION_PUBLICA_Y_RENDICION_DE_CUENTAS_DE_LA_CDMX_5.1.docx
# Procesando DOCX: REGLAMENTODELALEYAMBIENTALDELDISTRITOFEDERALENMATERIADEAUTORREGULACIONYAUDITORIASAMBIENTALES3.docx
# Procesando DOCX: Codigo_Procedimientos_Civiles_DF_2.2.docx
# Procesando DOCX: RGTO_DE_ESCALAFON_TRAB_DE_BASE_DE_LA_APDF3.docx
# Procesando DOCX: RGTO_DE_LA_LEY_DE_SALUD_MENTAL_DEL_DISTRITO_FEDERAL_3.docx
# Procesando PDF: REGLAMENTO_INTERIOR_DE_LA_COMISION_DE_BOX_PROFESIONAL_DEL_DISTRITO_FEDERAL_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando PDF: REGLAMENTO_INTERNO_DE_LA_COMISION_AMBIENTAL_METROPOLITANA_DEL_DF.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_REGULA_USO_DE_LA_FUERZA_PUBLICA_DF_1.1.docx
# Procesando DOCX: LEY_DE_LA_CAJA_DE_PREVISION_DE_LA_POLICIA_PREVENTIVA_DEL_DF_3.docx
# Procesando DOCX: RGTO_LEY_DE_PROPIEDAD_EN_CONDOMINIO_DE_INMUEBLES_PARA_EL_DISTRITO_FEDERAL_1.docx
# Procesando DOCX: LEY_PARA_LA_RET_POR_SERV_AMB_EN_SUELO_DE_CONSERV_3.1.docx
# Procesando DOCX: RGTO_INT_COMISION_EJECUTIVA_DE_COORD_METROPOLITANA_2.docx
# Procesando DOCX: RGTO_LEY_DE_LOS_DERE_DE_LAS_PERS_JOVENES_EN_LA_CIUDAD_DE_MEXICO_2.docx
# Procesando DOCX: Reglamento_de_la_Ley_de_Voluntad_Anticipada_del_Distrito_Federal_1.docx
# Procesando DOCX: LEY_DE_DESARRLLO_AGROPECUARIO_RURAL_Y_SUSTENTABLE_DE_LA_CDMX_2.docx
# Procesando DOCX: REGLAMENTO_PARA_EL_CONTROL_DE_ESTACIONAMIENTO_EN_VIA_PUBLICA_DE_LA_CDMX_10.docx
# Procesando DOCX: RGTO_DE_LA_LEY_DERECHO_A_PENSION_ADULTOS_MAYORES_DE_68_AOS_2.docx
# Procesando DOCX: LEY_DE_ECONOMIA_CIRCULAR_DE_LA_CDMX.docx
# Procesando DOCX: LEY_PARA_LA_ATENCION_INTEGRAL_DEL_VIH_SIDA_DEL_DF_2.docx
# Procesando DOCX: LEY_DE_ATN_INT_PARA_EL_DESARROLLO_DE_NINAS_YnINOS_EN_PRIMERA_INFANCIA_1.1.docx
# Procesando DOCX: LEY_PARA_EL_DESARROLLO_ECONOMICO_DE_LA_CDMX_1.1.docx
# Procesando DOCX: LEY_DE_JUSTICIA_ALTERNATIVA_DEL_TRIBUNAL_SUPERIOR_DE_JUSTICIA_PARA_EL_DF_2.1.docx
# Procesando DOCX: LEY_PARALA_ATENCION_INTEGRAL_DE_SUSTANCIAS_PSICOACTIVAS_DEL_DF_2.3.docx
# Procesando DOCX: RGTO_LEY_DE_PROTECCION_A_LOS_ANIMALES_DEL_DISTRITO_FEDERAL_1.docx
# Procesando DOCX: RGTO_IECDMX_REBASE_TOPE_DE_GASTOS_CAMPANA2.docx
# Procesando DOCX: LEY_DEL_SEGURO_EDUCATIVO_PARA_EL_DF_3.docx
# Procesando DOCX: REGLAMENTO_DE_CEMENTERIOS_CREMATORIOS_Y_SERVICIOS_FUNERARIOS_4.3.docx
# Procesando DOCX: Reglamento_de_la_Agencia_de_Proteccion_Sanitaria_del_Gob_CDMX4.docx
# Procesando DOCX: Codigo_de_etica_de_los_servidores_publicos_del_DF_3.docx
# Procesando DOCX: LEY_DEL_SISTEMA_INTEGRAL_DE_DERECHOS_HUMANOS_CDMX_1.1.docx
# Procesando DOCX: LEY_DE_VICTIMAS_PARA_LA_CDMX_5.docx
# Procesando DOCX: LEY_ORG_FISCALIA_ESPECIAL_EN_COMBATE_A_LA_CORRUPCION_1.2.docx
# Procesando DOCX: LEY_DE_OPERACION_E_INNOVACION_DIGITAL_PARA_LA_CIUDAD_DE_MEXICO_3.1.docx
# Procesando DOCX: LEY_DE_RESPON_CIVIL_PARA_LA_PROTECCION_DEL_DRCHO_A_LA_VIDA_PRIV_EL_HONOR_Y_LA_PROPIA_IMGEN_EN_EL_DF_2.1.docx
# Procesando DOCX: LEY_DE_RESPONSABILIDAD_PATRIMONIAL_DEL_DF_2.docx
# Procesando DOCX: LEY_DE_ACCESIBILIDAD_PARA_LA_CDMX_3.1.docx
# Procesando DOCX: LEY_DE_SEGURIDAD_PRIVADA_PARA_EL_DF_2.2.docx
# Procesando DOCX: REGLAMENTO_DE_LA_LEY_QUE_REGULA_EL_FUNCIONAMIENTO_DE_LOS_CENTROS_DE_ATENCION_Y_CUIDADO_INFANTIL_PARA_EL_DISTRITO_FEDERAL_2.docx
# Procesando DOCX: LEY_DE_CIUDADANIA_DIGITAL_DE_LA_CIUDAD_DE_MEXICO_2.3.docx
# Procesando DOCX: RGTO_UNIF_CONDEC_INSIGN_Y_EQUIPO_DE_LA_POLICIA_DE__LA_CDMX.docx
# Procesando DOCX: RGTO_DE_LA_LEY_DE_TURISMO_DE_LA_CDMX_1.docx
# Procesando DOCX: LEY_DERECHOS_DE_PUEBLOS_Y_BARRIOS_ORIGINARIOS_Y_COMUNIDADES_INDIGENAS_RESIDENTES_EN_LA_CDMX_2.4.docx
# Procesando DOCX: RTO_LEY_DE_PUBLICIDAD_EXTERIOR_CDMX_2.6.docx
# Procesando DOCX: LEY_PARA_RECONOCIMIENTO_Y_LA_ATENCION_DE_LAS_PERSONAS_LGBTTTI_DE_LA_CDMX_4.1.docx
# Procesando DOCX: LEY_DE_PATRIMONIO_CULTURAL_NATURAL_Y_BIOCULTURAL_DE_LA_CIUDAD_DE_MEXICO_2.7.docx
# Procesando DOCX: Rgto_en_Materia_de_Relaciones_Laborales_del_Tribunal_Electoral_del_Distrito_Federal_2.docx
# Procesando DOCX: LEY_DE_CUID_ALT_NINAS_NINOS_Y_ADOL_EN_EL_DF_3.docx
# Procesando DOCX: LEY_DE_ENTREGA_RECEPCION_DE_LOS_RECURSOS_DE_LA_ADMINISTRACION_PUBLICA_DE_LA_CDMX_2.2.docx
# Procesando DOCX: RGT_LIQ_DEL_PATR_DE_ASOCIACIONES_POLITICAS_DE_LA_CIUDAD_DE_MEXICO3.docx
# Procesando DOCX: RGTO_DE_LA_LEY_DE20RESIDUOS_SOLIDOS_DEL_DISTRITO_FEDERAL_1.docx
# Procesando DOCX: Ley_para_la_Celebracion_de_Espectaculos_Publicos_de_la_CDMX_3.3.docx
# Procesando DOCX: CODIGO_DE_RESPONSABILIDAD_PARLAMENTARIA_DEL_CONGRESO_DE_LA_CIUDAD_DE_MEXICO_2.1.docx
# Procesando DOCX: LEY_DEL_SISTEMA_PUBLICO_DE_RADIODIFUSION_DE_LA_CIUDAD_DE_MEXICO_2.2.docx
# Procesando DOCX: LEY_DE_JUSTICIA_ALTERNATIVA_EN_LA_PROCURACION_DE_JUSTICIA_PARA_EL_DF_1.2.docx
# Procesando DOCX: LEY_DE_PROCEDIMIENTO_ADMINISTRATIVO_DE_LA_CDMX_1.1.docx
# Procesando DOCX: LEY_PARA_PREVENIR_Y_ELIMINAR_LA_DISCRIMINACION_DE_LA_CDMX_5.1.docx
# Procesando DOCX: RGTO_INT_JUNTA_GOBIERNO_EAP_2.docx
# Procesando DOCX: LEY_ORGANICA_DE_LA_SSC_CDMX_7.docx
# Procesando DOCX: REGLAMENTO_INTERIOR_DEL_CONSEJO_DE_LA_JUDICATURA_DE_LA_CIUDAD_DE_MEXICO_3.3.docx
# Procesando DOCX: RGTO_INTERIOR_COMISIONES_ASAMBLEA_LEGISLATIVA_DEL_D_F_2.docx
# Procesando DOCX: REGLAMENTO_DE_LA_LEY_DE_EXTINCION_DE_DOMINIO_PARA_EL_DISTRITO_FEDERAL_2.docx
# Procesando DOCX: RGTO_LEY_DEL_FONDO_DE_APOYO_A_LA_PROCURACION_DE_JUSTICIA_EN_EL_DF_2.docx
# Procesando DOCX: LEY_BUSQUEDA_DE_PERSONAS_DE_LA_CDMX_2.4.docx
# Procesando DOCX: RGTO_LEY_DE_INFRAESTRUCTURA_FISICA_EDUCATIVA_DEL_DISTRITO_FEDERAL_2.docx
# Procesando DOCX: LEY_PARA_LA_PROMOCION_DE_LA_CONVIVENCIA_LIBRE_DE_VIOLENCIA_EN_EL_ENTORNO_ESCOLAR_DE_LA_CIUDAD_DE_MEXICO_2.3.docx
# Procesando DOCX: RGTO_LEY_AMB_DF_EN_MATERIA_DE_VERIFICACION_VEHICULAR3.docx
# Procesando DOCX: REGLAMENTOINTERNODELCONSEJOPARALAPREVENSIONYLAATENCIONINTEGRALDELVIHSIDA.docx
# Procesando DOCX: REGLAMENTOINTERNODEOPERACIONDELOSCENTROSDEJUSTICIAPARALASMUJERESENLACIUDADDEMEXICO1.docx
# Procesando DOCX: RGTO_LEY_ORG_PAOT_2.docx
# Procesando DOCX: LEY_PARA_PREVENIR_LA_VIOLENCIA_EN20_LOS_ESPECTACULOS_DEPORTIVOS_EN_LA_CDMX_2.docx
# Procesando PDF: REGLAMENTO_PARA_EL_USO_Y_PRESERVACION_DEL_BOSQUE_DE_SAN_JUAN_DE_ARAGON_1.pdf (recortando 20mm arriba, 20mm abajo)
# Procesando DOCX: LEY_DE_EVALUACION_DE_LA_CDMX_4.docx
# Procesando DOCX: LEY_DERECHO_ACC_DISP_Y_SANEAMIENTO_DEL20AGUA_DE_LA_CIUDAD_DE_MEXICO_4.1.docx
# Procesando DOCX: REGLAMENTO_DE_MERCADOS_PARA_EL_DISTRITO_FEDERAL3.docx
# Procesando DOCX: LEY_DEL_SISTEMA_DE_ALERTA_SOCIAL_DE_LA_CDMX_2.5.docx
# Procesando DOCX: LEY_PARA_LA_ATENCION_INTEGRAL_DELcANCER_DE_MAMA_DEL_DF_2.3.docx
# Procesando DOCX: REGLAMENTO_INTERN_DEL_COM_TEC_REG_DE_ESTAD_Y_DE_INF_GEOG_DEL_DF.docx
# Procesando DOCX: RGTO_DE_LA_LEY_PARA_EL_DESARR_DE_LA_COMPE_DE_LAS_MIPYMES_2.docx
# Procesando DOCX: LEY_DE_EDUCACION_DE_LA_CDMX_3.4.docx
# Procesando DOCX: LEY_DE_SALUD_DE_LA_CIUDAD_DE_MEXICO_3.3.docx
# Procesando DOCX: LEY_20DE_JUSTICIA_ADMINISTRATIVA_DE_LA_CDMX_3.1.docx
# Procesando DOCX: LEY_ORGANICA_DE_LA_ESCUELA_DE_ADM_PUBLICA_DE20LA20_CDMX_1.2.docx
# Procesando DOCX: REGLAMENTODELALEYAMBIENTALDELDISTRITOFEDERAL_3.docx
# Procesando DOCX: REGLAMENTODESESIONESDELCONSEJOPARAPREVENIRYERRADICARLADISCRIMINACIONDELDF3.docx
#
# Total de artículos extraídos: 31037
# Total de documentos únicos: 338
#
# Primeros 5 artículos:
#                                              Archivo    Articulo  \
# 0  RGTO_DE_LA_LEY_DE_CENTROS_PENITENCIARIOS_DE_LA...  Artículo 1
# 1  RGTO_DE_LA_LEY_DE_CENTROS_PENITENCIARIOS_DE_LA...  Artículo 2
# 2  RGTO_DE_LA_LEY_DE_CENTROS_PENITENCIARIOS_DE_LA...  Artículo 3
# 3  RGTO_DE_LA_LEY_DE_CENTROS_PENITENCIARIOS_DE_LA...  Artículo 4
# 4  RGTO_DE_LA_LEY_DE_CENTROS_PENITENCIARIOS_DE_LA...  Artículo 5
#
#                                                Texto
# 0  Las disposiciones contenidas en este Reglament...
# 1  La aplicación del presente Reglamento correspo...
# 2  Para los efectos del presente Reglamento, adem...
# 3  Sin perjuicio de los principios que prevén los...
# 4  El tratamiento para la persona privada de su l...
#
# Artículos con texto < 20 caracteres: 370
# Ejemplos:
#                                                 Archivo      Articulo  \
# 976   RGTO_LEY_DE_GESTION_INTEGRAL_DE_RIESGOS_Y_PROT...  Artículo 117
# 1033  RGTO_LEY_DE_GESTION_INTEGRAL_DE_RIESGOS_Y_PROT...  Artículo 174
# 1034  RGTO_LEY_DE_GESTION_INTEGRAL_DE_RIESGOS_Y_PROT...  Artículo 175
# 1035  RGTO_LEY_DE_GESTION_INTEGRAL_DE_RIESGOS_Y_PROT...  Artículo 176
# 1096  RGTO_LEY_DE_GESTION_INTEGRAL_DE_RIESGOS_Y_PROT...  Artículo 227
# 1718  LEY_DE_GESTION_INTEGRAL_DE_RIESGOS_Y_PROTECCIO...   Artículo 57
# 2001  LEY_DE_LA_SALA_CONSTITUCIONAL_DEL_PODER_JUDICI...    Artículo 1
# 2002  LEY_DE_LA_SALA_CONSTITUCIONAL_DEL_PODER_JUDICI...    Artículo 2
# 2003  LEY_DE_LA_SALA_CONSTITUCIONAL_DEL_PODER_JUDICI...    Artículo 3
# 2004  LEY_DE_LA_SALA_CONSTITUCIONAL_DEL_PODER_JUDICI...    Artículo 4
#
#            Texto
# 976   Se deroga.
# 1033  Se deroga.
# 1034  Se deroga.
# 1035   Se deroga
# 1096  Se deroga.
# 1718  Se deroga.
# 2001   Se deroga
# 2002   Se deroga
# 2003   Se deroga
# 2004   Se deroga
#
# Archivo guardado en: /Users/alexa/Projects/cdmx_pipeline/data/01_input/extracted_articles.xlsx

# %%
df.shape
# Out:
# (31037, 3)

# %%
df.head()
# Out:
#                                              Archivo    Articulo  \
# 0  RGTO_DE_LA_LEY_DE_CENTROS_PENITENCIARIOS_DE_LA...  Artículo 1
# 1  RGTO_DE_LA_LEY_DE_CENTROS_PENITENCIARIOS_DE_LA...  Artículo 2
# 2  RGTO_DE_LA_LEY_DE_CENTROS_PENITENCIARIOS_DE_LA...  Artículo 3
# 3  RGTO_DE_LA_LEY_DE_CENTROS_PENITENCIARIOS_DE_LA...  Artículo 4
# 4  RGTO_DE_LA_LEY_DE_CENTROS_PENITENCIARIOS_DE_LA...  Artículo 5
#
#                                                Texto
# 0  Las disposiciones contenidas en este Reglament...
# 1  La aplicación del presente Reglamento correspo...
# 2  Para los efectos del presente Reglamento, adem...
# 3  Sin perjuicio de los principios que prevén los...
# 4  El tratamiento para la persona privada de su l...
