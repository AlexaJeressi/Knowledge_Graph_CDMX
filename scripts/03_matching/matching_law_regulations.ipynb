# %%
import pandas as pd
import sys
import time
from difflib import SequenceMatcher
from tqdm import tqdm
import time
from multiprocessing import Pool, cpu_count
import numpy as np

sys.path.append('../functions')
from hash_functions import normalize_text_for_hash


# Cargar el archivo generado en el paso anterior (hash_creation.ipynb)
df = pd.read_csv('../../data/03_extracted/regulation_mentions_extracted.csv')
df = df[~df['art_id'].str.contains('_TRANS', na=False)]
df.head()
# Out:
#       doc_id        art_id                    entity_text       entity_label  \
# 2   37159EFC   37159EFC_19         Reglamento de esta Ley  LEY_Y_REGLAMENTOS
# 4   3A2C8488  3A2C8488_168  Reglamento de la presente Ley  LEY_Y_REGLAMENTOS
# 7   C57B66D6   C57B66D6_92         Reglamento de esta ley  LEY_Y_REGLAMENTOS
# 8   C57B66D6  C57B66D6_100         Reglamento de esta Ley  LEY_Y_REGLAMENTOS
# 10  6DAE5BFB   6DAE5BFB_20         Reglamento de esta Ley  LEY_Y_REGLAMENTOS
#
#             pattern_group                                       full_context  \
# 2   SPECIFIC_LAW_MENTIONS  Federal que haya sido solicitado por un produc...
# 4   SPECIFIC_LAW_MENTIONS  Consejo de Resiliencia tendrá órganos de traba...
# 7   SPECIFIC_LAW_MENTIONS  , dentro del plazo a que se refiere el párrafo...
# 8   SPECIFIC_LAW_MENTIONS  Vicies . En lo no previsto en esta sección y t...
# 10  SPECIFIC_LAW_MENTIONS  que se integrará por un representante de cada ...
#
#     words_before_count  words_after_count
# 2                   30                 30
# 4                   30                  1
# 7                   30                 30
# 8                   28                 10
# 10                  30                 30

# %%
ley_reglamentos = df[df['entity_label'].isin(['LEY_Y_REGLAMENTOS','LEY_CON_REGLAMENTOS'])]

ley_reglamentos['entity_text'].unique()
# Out:
# array(['Reglamento de esta Ley', 'Reglamento de la presente Ley',
#        'Reglamento de esta ley', 'esta ley y sus reglamentos',
#        'reglamento de la presente Ley', 'reglamento de esta Ley',
#        'esta Ley y sus reglamentos', 'reglamento de esta ley',
#        'reglamento de la presente ley', 'esta Ley y sus Reglamentos',
#        'esta Ley y con el reglamento', 'Reglamento de la presente ley'],
#       dtype=object)

# %%
# Leer el archivo con el nombre de las leyes completas 
leyes_completas = pd.read_csv('../../data/02_catalogs/leyes_hash.csv')
leyes_completas.head()
# Out:
#                                               nombre fecha_publicacion  \
# 0       Constitucion Politica de la Ciudad de Mexico          05/02/17
# 1  Ley de Proteccion de Datos Personales en Poses...          03/10/08
# 2  Ley de Acceso de las Mujeres a una Vida Libre ...          25/06/25
# 3  Ley de los Derechos de Ninas Ninos y Adolescen...          02/04/25
# 4  Ley para el Reconocimiento y la Atencion de la...          31/03/25
#
#   fecha_actualizacion                                           link_pdf  \
# 0                 NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
# 1                 NaN  https://data.consejeria.cdmx.gob.mx//images/le...
# 2                 NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
# 3                 NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
# 4                 NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
#
#                                            link_docx  \
# 0  https://data.consejeria.cdmx.gob.mx/images/ley...
# 1                                                NaN
# 2  https://data.consejeria.cdmx.gob.mx/images/ley...
# 3  https://data.consejeria.cdmx.gob.mx/images/ley...
# 4  https://data.consejeria.cdmx.gob.mx/images/ley...
#
#                                           source_url gov_level  \
# 0  https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 1  https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 2  https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 3  https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 4  https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
#
#                                    nombre_normalized    doc_id
# 0             CONSTITUCIONPOLITICADELACIUDADDEMEXICO  234F69A3
# 1  LEYDEPROTECCIONDEDATOSPERSONALESENPOSESIONDESU...  80360428
# 2  LEYDEACCESODELASMUJERESAUNAVIDALIBREDEVIOLENCI...  74FF23BF
# 3  LEYDELOSDERECHOSDENINASNINOSYADOLESCENTESDELAC...  FB6CCCAE
# 4  LEYPARAELRECONOCIMIENTOYLAATENCIONDELASPERSONA...  6C800A8E

# %%
# Hacer un left join de el nombre y el tipo de ley a las menciones actuales. 
# De esta manera se obtiene el nombre de la ley de cada uno de los acrtículos 
# Entonces su puede saber de que ley y de que reglamenot de está hablando. 

ley_reglamentos = ley_reglamentos.join(
    leyes_completas[['doc_id', 'nombre']].set_index('doc_id'), 
    on='doc_id', 
    how='left'
)

# Crear el nombre del reglamento al que hace referencia la mención
ley_reglamentos['nombre_reglamento'] =  'Reglamento de la' + ' ' +ley_reglamentos['nombre']


ley_reglamentos['nombre_reglamento_normalized'] = ley_reglamentos['nombre_reglamento'].apply(normalize_text_for_hash)

ley_reglamentos.shape
# Out:
# (217, 11)

# %%
ley_reglamentos = ley_reglamentos[~ley_reglamentos['nombre'].str.startswith('Regla', na=False)]
ley_reglamentos.shape
# Out:
# (215, 11)

# %%
ley_reglamentos.shape
ley_reglamentos
# Out:
#        doc_id        art_id                    entity_text  \
# 2    37159EFC   37159EFC_19         Reglamento de esta Ley
# 4    3A2C8488  3A2C8488_168  Reglamento de la presente Ley
# 7    C57B66D6   C57B66D6_92         Reglamento de esta ley
# 8    C57B66D6  C57B66D6_100         Reglamento de esta Ley
# 10   6DAE5BFB   6DAE5BFB_20         Reglamento de esta Ley
# ..        ...           ...                            ...
# 286  AF96B37C  AF96B37C_129  Reglamento de la presente Ley
# 287  AF96B37C  AF96B37C_131  Reglamento de la presente Ley
# 288  AF96B37C  AF96B37C_159     esta ley y sus reglamentos
# 289  AF96B37C  AF96B37C_159     esta ley y sus reglamentos
# 290  AF96B37C  AF96B37C_175         Reglamento de esta Ley
#
#             entity_label          pattern_group  \
# 2      LEY_Y_REGLAMENTOS  SPECIFIC_LAW_MENTIONS
# 4      LEY_Y_REGLAMENTOS  SPECIFIC_LAW_MENTIONS
# 7      LEY_Y_REGLAMENTOS  SPECIFIC_LAW_MENTIONS
# 8      LEY_Y_REGLAMENTOS  SPECIFIC_LAW_MENTIONS
# 10     LEY_Y_REGLAMENTOS  SPECIFIC_LAW_MENTIONS
# ..                   ...                    ...
# 286    LEY_Y_REGLAMENTOS  SPECIFIC_LAW_MENTIONS
# 287    LEY_Y_REGLAMENTOS  SPECIFIC_LAW_MENTIONS
# 288  LEY_CON_REGLAMENTOS  SPECIFIC_LAW_MENTIONS
# 289  LEY_CON_REGLAMENTOS  SPECIFIC_LAW_MENTIONS
# 290    LEY_Y_REGLAMENTOS  SPECIFIC_LAW_MENTIONS
#
#                                           full_context  words_before_count  \
# 2    Federal que haya sido solicitado por un produc...                  30
# 4    Consejo de Resiliencia tendrá órganos de traba...                  30
# 7    , dentro del plazo a que se refiere el párrafo...                  30
# 8    Vicies . En lo no previsto en esta sección y t...                  28
# 10   que se integrará por un representante de cada ...                  30
# ..                                                 ...                 ...
# 286  El tratamiento de personas con consumo de sust...                  22
# 287  Ciudad de México que presten servicios de aten...                  30
# 288  le correspondan al Gobierno ; Hacer del conoci...                  30
# 289  le correspondan al Gobierno ; Hacer del conoci...                  30
# 290  los certificados de defunción que requiera la ...                  30
#
#      words_after_count                                             nombre  \
# 2                   30          Ley de Filmaciones de la Ciudad de Mexico
# 4                    1  Ley de Gestion Integral de Riesgos y Proteccio...
# 7                   30         Ley del Notariado para la Ciudad de Mexico
# 8                   10         Ley del Notariado para la Ciudad de Mexico
# 10                  30      Ley de Adquisiciones para el Distrito Federal
# ..                 ...                                                ...
# 286                 13                Ley de Salud de la Ciudad De Mexico
# 287                  1                Ley de Salud de la Ciudad De Mexico
# 288                 30                Ley de Salud de la Ciudad De Mexico
# 289                 30                Ley de Salud de la Ciudad De Mexico
# 290                 28                Ley de Salud de la Ciudad De Mexico
#
#                                      nombre_reglamento  \
# 2    Reglamento de la Ley de Filmaciones de la Ciud...
# 4    Reglamento de la Ley de Gestion Integral de Ri...
# 7    Reglamento de la Ley del Notariado para la Ciu...
# 8    Reglamento de la Ley del Notariado para la Ciu...
# 10   Reglamento de la Ley de Adquisiciones para el ...
# ..                                                 ...
# 286  Reglamento de la Ley de Salud de la Ciudad De ...
# 287  Reglamento de la Ley de Salud de la Ciudad De ...
# 288  Reglamento de la Ley de Salud de la Ciudad De ...
# 289  Reglamento de la Ley de Salud de la Ciudad De ...
# 290  Reglamento de la Ley de Salud de la Ciudad De ...
#
#                           nombre_reglamento_normalized
# 2     REGLAMENTODELALEYDEFILMACIONESDELACIUDADDEMEXICO
# 4    REGLAMENTODELALEYDEGESTIONINTEGRALDERIESGOSYPR...
# 7    REGLAMENTODELALEYDELNOTARIADOPARALACIUDADDEMEXICO
# 8    REGLAMENTODELALEYDELNOTARIADOPARALACIUDADDEMEXICO
# 10   REGLAMENTODELALEYDEADQUISICIONESPARAELDISTRITO...
# ..                                                 ...
# 286         REGLAMENTODELALEYDESALUDDELACIUDADDEMEXICO
# 287         REGLAMENTODELALEYDESALUDDELACIUDADDEMEXICO
# 288         REGLAMENTODELALEYDESALUDDELACIUDADDEMEXICO
# 289         REGLAMENTODELALEYDESALUDDELACIUDADDEMEXICO
# 290         REGLAMENTODELALEYDESALUDDELACIUDADDEMEXICO
#
# [215 rows x 11 columns]

# %%
# Leer la tabla de leyes completas
leyes_completas = pd.read_csv('../../data/02_catalogs/leyes_hash.csv')
leyes_completas = leyes_completas[leyes_completas['nombre_normalized'].str.startswith('REGLA', na=False)]


leyes_completas.head()
# Out:
#                                                 nombre fecha_publicacion  \
# 181  Reglamento de la Ley de Turismo de la Ciudad d...          25/09/24
# 182  Reglamento del Registro Civil de la Ciudad de ...          25/09/24
# 183  Reglamento de la Ley de Establecimientos Merca...          25/09/24
# 184  Reglamento de la Ley de Cultura Civica de la C...          25/09/24
# 185  Reglamento de la Ley del Notariado en la Ciuda...          25/09/24
#
#     fecha_actualizacion                                           link_pdf  \
# 181                 NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
# 182                 NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
# 183                 NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
# 184                 NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
# 185                 NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
#
#                                              link_docx  \
# 181  https://data.consejeria.cdmx.gob.mx/images/ley...
# 182  https://data.consejeria.cdmx.gob.mx/images/ley...
# 183                                                NaN
# 184                                                NaN
# 185  https://data.consejeria.cdmx.gob.mx/images/ley...
#
#                                             source_url gov_level  \
# 181  https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 182  https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 183  https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 184  https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 185  https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
#
#                                      nombre_normalized    doc_id
# 181       REGLAMENTODELALEYDETURISMODELACIUDADDEMEXICO  FAA2EE90
# 182       REGLAMENTODELREGISTROCIVILDELACIUDADDEMEXICO  4198B460
# 183  REGLAMENTODELALEYDEESTABLECIMIENTOSMERCANTILES...  7566EC96
# 184  REGLAMENTODELALEYDECULTURACIVICADELACIUDADDEME...  C6E9B915
# 185    REGLAMENTODELALEYDELNOTARIADOENLACIUDADDEMEXICO  D2CE6E11

# %%
def match_official_docs(oficial_docs_df, leyes_completas_df, threshold=0.8):
    """
    Matching entre entity_text y name con estrategia de fallback.
    Si el match original no es > 0.9, intenta con 'ciudad de mexico' -> 'distrito federal'.
    Con timer y barra de progreso.
    """
    start_time = time.time()
    results = []
    
    print(f"Iniciando matching de {len(oficial_docs_df):,} documentos oficiales contra {len(leyes_completas_df):,} referencias...")
    print(f"Threshold: {threshold}")
    print(f"Total de comparaciones: {len(oficial_docs_df) * len(leyes_completas_df):,}")
    
    # Agregar barra de progreso
    for idx, row in tqdm(oficial_docs_df.iterrows(), total=len(oficial_docs_df), desc="Procesando"):
        entity_text_original = row['nombre_reglamento_normalized']
        art_id = row['art_id']
        
        # Crear versión alternativa reemplazando "CIUDADDEMEXICO" por "DISTRITOFEDERAL"
        entity_text_created = entity_text_original.replace('CIUDADDEMEXICO', 'DISTRITOFEDERAL')
        
        best_match = None
        best_match_name = None
        best_score = 0
        match_version = ''
        
        # PRIMER INTENTO: Buscar el mejor match con el nombre original
        for _, law_row in leyes_completas_df.iterrows():
            law_name = law_row['nombre_normalized']
            doc_id = law_row['doc_id']
            
            # Calcular similitud
            similarity = SequenceMatcher(None, entity_text_original.lower(), law_name.lower()).ratio()
            
            if similarity > best_score and similarity >= threshold:
                best_score = similarity
                best_match = doc_id
                best_match_name = law_row['nombre']
                match_version = 'original'
        
        # SEGUNDO INTENTO: Si el match no es > 0.9 y hay una versión alternativa diferente, intentar con ella
        if best_score <= 0.9 and entity_text_created != entity_text_original:
            for _, law_row in leyes_completas_df.iterrows():
                law_name = law_row['nombre_normalized']
                doc_id = law_row['doc_id']
                
                # Calcular similitud con la versión alternativa
                similarity = SequenceMatcher(None, entity_text_created.lower(), law_name.lower()).ratio()
                
                if similarity > best_score and similarity >= threshold:
                    best_score = similarity
                    best_match = doc_id
                    best_match_name = law_row['nombre']
                    match_version = 'created'
        
        # Agregar resultado
        results.append({
            'art_id': art_id,
            'nombre_reglamento_normalized': entity_text_original,
            'nombre_reglamento_normalized_created': entity_text_created,
            'match_version_used': match_version,
            'doc_id': best_match if best_match else '',
            'nombre_ley_matched': best_match_name if best_match_name else '',
            'similarity': best_score if best_match else 0
        })
    
    elapsed_time = time.time() - start_time
    print(f"\nMatching completado en {elapsed_time:.2f} segundos ({elapsed_time/60:.2f} minutos)")
    print(f"Matches encontrados: {sum(1 for r in results if r['doc_id'])}")
    print(f"Matches con versión original: {sum(1 for r in results if r['match_version_used'] == 'original')}")
    print(f"Matches con versión creada (distrito federal): {sum(1 for r in results if r['match_version_used'] == 'created')}")
    
    return pd.DataFrame(results)

# %%
results = match_official_docs(ley_reglamentos, leyes_completas, threshold=0.9)
results
# Out:
# Iniciando matching de 215 documentos oficiales contra 291 referencias...
# Threshold: 0.9
# Total de comparaciones: 62,565
# Procesando:   0%|          | 0/215 [00:00<?, ?it/s]
# Procesando: 100%|██████████| 215/215 [00:13<00:00, 16.15it/s]
# Matching completado en 13.32 segundos (0.22 minutos)
# Matches encontrados: 184
# Matches con versión original: 112
# Matches con versión creada (distrito federal): 72
#            art_id                       nombre_reglamento_normalized  \
# 0     37159EFC_19   REGLAMENTODELALEYDEFILMACIONESDELACIUDADDEMEXICO
# 1    3A2C8488_168  REGLAMENTODELALEYDEGESTIONINTEGRALDERIESGOSYPR...
# 2     C57B66D6_92  REGLAMENTODELALEYDELNOTARIADOPARALACIUDADDEMEXICO
# 3    C57B66D6_100  REGLAMENTODELALEYDELNOTARIADOPARALACIUDADDEMEXICO
# 4     6DAE5BFB_20  REGLAMENTODELALEYDEADQUISICIONESPARAELDISTRITO...
# ..            ...                                                ...
# 210  AF96B37C_129         REGLAMENTODELALEYDESALUDDELACIUDADDEMEXICO
# 211  AF96B37C_131         REGLAMENTODELALEYDESALUDDELACIUDADDEMEXICO
# 212  AF96B37C_159         REGLAMENTODELALEYDESALUDDELACIUDADDEMEXICO
# 213  AF96B37C_159         REGLAMENTODELALEYDESALUDDELACIUDADDEMEXICO
# 214  AF96B37C_175         REGLAMENTODELALEYDESALUDDELACIUDADDEMEXICO
#
#                   nombre_reglamento_normalized_created match_version_used  \
# 0    REGLAMENTODELALEYDEFILMACIONESDELADISTRITOFEDERAL            created
# 1    REGLAMENTODELALEYDEGESTIONINTEGRALDERIESGOSYPR...           original
# 2    REGLAMENTODELALEYDELNOTARIADOPARALADISTRITOFED...           original
# 3    REGLAMENTODELALEYDELNOTARIADOPARALADISTRITOFED...           original
# 4    REGLAMENTODELALEYDEADQUISICIONESPARAELDISTRITO...           original
# ..                                                 ...                ...
# 210        REGLAMENTODELALEYDESALUDDELADISTRITOFEDERAL            created
# 211        REGLAMENTODELALEYDESALUDDELADISTRITOFEDERAL            created
# 212        REGLAMENTODELALEYDESALUDDELADISTRITOFEDERAL            created
# 213        REGLAMENTODELALEYDESALUDDELADISTRITOFEDERAL            created
# 214        REGLAMENTODELALEYDESALUDDELADISTRITOFEDERAL            created
#
#        doc_id                                 nombre_ley_matched  similarity
# 0    807464C1  Reglamento de la Ley de Filmaciones del Distri...    0.989691
# 1    D61F4C69  Reglamento de la Ley de Gestion Integral de Ri...    1.000000
# 2    D2CE6E11  Reglamento de la Ley del Notariado en la Ciuda...    0.937500
# 3    D2CE6E11  Reglamento de la Ley del Notariado en la Ciuda...    0.937500
# 4    47C1641A  Reglamento de la Ley de Adquisiciones para el ...    1.000000
# ..        ...                                                ...         ...
# 210  87EDE287  Reglamento de la Ley de Salud del Distrito Fed...    0.988235
# 211  87EDE287  Reglamento de la Ley de Salud del Distrito Fed...    0.988235
# 212  87EDE287  Reglamento de la Ley de Salud del Distrito Fed...    0.988235
# 213  87EDE287  Reglamento de la Ley de Salud del Distrito Fed...    0.988235
# 214  87EDE287  Reglamento de la Ley de Salud del Distrito Fed...    0.988235
#
# [215 rows x 7 columns]

# %%
results[(results['similarity'] < 0.95) & (results['similarity'] > 0) & (~results['art_id'].str.contains('_TRANS', na=False))]
# Out:
#              art_id                       nombre_reglamento_normalized  \
# 2       C57B66D6_92  REGLAMENTODELALEYDELNOTARIADOPARALACIUDADDEMEXICO
# 3      C57B66D6_100  REGLAMENTODELALEYDELNOTARIADOPARALACIUDADDEMEXICO
# 19      D0D23E5F_33  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 20      D0D23E5F_34  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 21      D0D23E5F_35  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 22      D0D23E5F_46  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 23      D0D23E5F_48  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 24      D0D23E5F_50  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 25      D0D23E5F_63  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 26      D0D23E5F_65  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 27      D0D23E5F_65  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 28      D0D23E5F_70  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 29      D0D23E5F_76  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 30      D0D23E5F_78  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 31      D0D23E5F_79  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 32     D0D23E5F_100  REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...
# 126      0CB5F9A5_8   REGLAMENTODELALEYDESALUDMENTALDELDISTRITOFEDERAL
# 127     0CB5F9A5_13   REGLAMENTODELALEYDESALUDMENTALDELDISTRITOFEDERAL
# 128     0CB5F9A5_15   REGLAMENTODELALEYDESALUDMENTALDELDISTRITOFEDERAL
# 129     0CB5F9A5_38   REGLAMENTODELALEYDESALUDMENTALDELDISTRITOFEDERAL
# 135     D26A0A36_15  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...
# 136     D26A0A36_35  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...
# 137     D26A0A36_37  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...
# 138     D26A0A36_39  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...
# 139     D26A0A36_41  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...
# 140     D26A0A36_42  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...
# 141  D26A0A36_59BIS  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...
#
#                   nombre_reglamento_normalized_created match_version_used  \
# 2    REGLAMENTODELALEYDELNOTARIADOPARALADISTRITOFED...           original
# 3    REGLAMENTODELALEYDELNOTARIADOPARALADISTRITOFED...           original
# 19   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 20   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 21   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 22   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 23   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 24   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 25   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 26   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 27   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 28   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 29   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 30   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 31   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 32   REGLAMENTODELALEYORGANICADELAFISCALIAGENERALDE...            created
# 126   REGLAMENTODELALEYDESALUDMENTALDELDISTRITOFEDERAL           original
# 127   REGLAMENTODELALEYDESALUDMENTALDELDISTRITOFEDERAL           original
# 128   REGLAMENTODELALEYDESALUDMENTALDELDISTRITOFEDERAL           original
# 129   REGLAMENTODELALEYDESALUDMENTALDELDISTRITOFEDERAL           original
# 135  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...            created
# 136  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...            created
# 137  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...            created
# 138  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...            created
# 139  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...            created
# 140  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...            created
# 141  REGLAMENTODELALEYDEPROTECCIONYBIENESTARDELOSAN...            created
#
#        doc_id                                 nombre_ley_matched  similarity
# 2    D2CE6E11  Reglamento de la Ley del Notariado en la Ciuda...    0.937500
# 3    D2CE6E11  Reglamento de la Ley del Notariado en la Ciuda...    0.937500
# 19   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 20   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 21   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 22   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 23   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 24   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 25   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 26   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 27   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 28   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 29   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 30   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 31   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 32   55FBF591  Reglamento de la Ley Organica de la Procuradur...    0.912752
# 126  2DC6EAD9  Reglamento de la Ley de Salud Mental para el D...    0.949495
# 127  2DC6EAD9  Reglamento de la Ley de Salud Mental para el D...    0.949495
# 128  2DC6EAD9  Reglamento de la Ley de Salud Mental para el D...    0.949495
# 129  2DC6EAD9  Reglamento de la Ley de Salud Mental para el D...    0.949495
# 135  CE7E985D  Reglamento de la Ley de Proteccion a los Anima...    0.907692
# 136  CE7E985D  Reglamento de la Ley de Proteccion a los Anima...    0.907692
# 137  CE7E985D  Reglamento de la Ley de Proteccion a los Anima...    0.907692
# 138  CE7E985D  Reglamento de la Ley de Proteccion a los Anima...    0.907692
# 139  CE7E985D  Reglamento de la Ley de Proteccion a los Anima...    0.907692
# 140  CE7E985D  Reglamento de la Ley de Proteccion a los Anima...    0.907692
# 141  CE7E985D  Reglamento de la Ley de Proteccion a los Anima...    0.907692

# %%
results[(results['similarity'] == 0) & (~results['art_id'].str.contains('_TRANS', na=False))]['nombre_reglamento_normalized'].unique()
# Out:
# array(['REGLAMENTODELALEYDELREGIMENPATRIMONIALYDELSERVICIOPUBLICO',
#        'REGLAMENTODELALEYDELOSDERECHOSCULTURALESDELOSHABITANTESYVISITANTESDELACIUDADDEMEXICO',
#        'REGLAMENTODELALEYQUEESTABLECEELDERECHOARECIBIRUNAPOYOALIMENTARIOALASMADRESSOLASDEESCASOSRECURSOSRESIDENTESENLACIUDADDEMEXICO',
#        'REGLAMENTODELALEYDEPLANEACIONDEMOGRAFICAYESTADISTICAPARALAPOBLACIONDELDISTRITOFEDERAL',
#        'REGLAMENTODELALEYPARALAPROTECCIONINTEGRALDEPERSONASDEFENSORASDEDERECHOSHUMANOSYPERIODISTASDELDISTRITOFEDERAL',
#        'REGLAMENTODELALEYDELADEFENSORIAPUBLICADELDISTRITOFEDERAL',
#        'REGLAMENTODELALEYQUEREGULAELUSODETECNOLOGIAPARALASEGURIDADPUBLICADELDISTRITOFEDERAL',
#        'REGLAMENTODELALEYDEBEBESEGURODELACIUDADDEMEXICO',
#        'REGLAMENTODELALEYDEFOMENTOPARALALECTURAYELLIBRODELACIUDADDEMEXICO',
#        'REGLAMENTODELALEYDELINSTITUTODEVERIFICACIONADMINISTRATIVADELACIUDADDEMEXICO',
#        'REGLAMENTODELALEYDECIUDADANIADIGITALDELACIUDADDEMEXICO',
#        'REGLAMENTODELALEYPARAELRECONOCIMIENTOYLAATENCIONDELASPERSONASLGBTTTIDELACIUDADDEMEXICO',
#        'REGLAMENTODELALEYDELDERECHOALACCESODISPOSICIONYSANEAMIENTODELAGUADELACIUDADDEMEXICO',
#        'REGLAMENTODELALEYDELSISTEMADEALERTASOCIALDELACIUDADDEMEXICO'],
#       dtype=object)

# %%
# Ninguno de estos reglamentos que no fueron matcheados existe.

# %%
results['type_of_relation'] = 'mencion_reglamento'
results.to_csv('../../data/04_matched/regulation_mentions_matched.csv', index=False)

# %% [markdown]
# Además de la mención al reglamento existe un mención al mismo documento

# %%
ley_reglamentos = df[df['entity_label'].isin(['LEY_Y_REGLAMENTOS','LEY_CON_REGLAMENTOS'])]
self_references_reglamentos = ley_reglamentos[['art_id','doc_id']]

self_references_reglamentos['type_of_relation'] = 'mencion_reglamento'

#self_references_reglamentos
self_references_reglamentos.to_csv('../../data/04_matched/regulation_mentions_matched_self_references.csv', index=False)
# Out:
# /var/folders/3p/n363h71s3gg0h1brsrv7f_zr0000gn/T/ipykernel_62514/524967706.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self_references_reglamentos['type_of_relation'] = 'mencion_reglamento'
