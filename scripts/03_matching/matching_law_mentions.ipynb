# %%
import pandas as pd
import sys
from tqdm import tqdm
import time
from multiprocessing import Pool, cpu_count
import numpy as np
import os
from openai import OpenAI

# Agregar path de funciones
sys.path.append('../functions')
from openai_law_matcher import (
    filter_official_regex_matches_parallel,
    apply_openai_law_matching_deduplicated
)

# %%
# Verificar que la API key está configurada
api_key = os.getenv('OPENAI_API_KEY')

# Inicializar cliente de OpenAI
client = OpenAI(api_key=api_key)

# %%
df = pd.read_csv('../../data/03_extracted/legal_docs_generic.csv')
df = df[~df['art_id'].str.contains('_TRANS', na=False)]

# %%
df.head()
# Out:
#      doc_id      art_id                                        entity_text  \
# 0  6D0C4493  6D0C4493_2  Ley de Centros Penitenciarios de la Ciudad de ...
# 1  6D0C4493  6D0C4493_3  Ley de Centros Penitenciarios de la Ciudad de ...
# 2  6D0C4493  6D0C4493_3                      Ley de Centros Penitenciarios
# 3  6D0C4493  6D0C4493_3  Ley de Centros Penitenciarios de la Ciudad de ...
# 4  6D0C4493  6D0C4493_3  Ley de Centros Penitenciarios de la Ciudad de ...
#
#   entity_label pattern_group  \
# 0  LAW_MENTION    LEGAL_DOCS
# 1  LAW_MENTION    LEGAL_DOCS
# 2  LAW_MENTION    LEGAL_DOCS
# 3  LAW_MENTION    LEGAL_DOCS
# 4  LAW_MENTION    LEGAL_DOCS
#
#                                         full_context  words_before_count  \
# 0  de Sanciones Administrativas y de Integración ...                  30
# 1  Para los efectos del presente Reglamento , ade...                  14
# 2  Sanciones Administrativas de la Ciudad de Méxi...                  30
# 3  de México ; Constitución Federal : Constitució...                  30
# 4  otras expresiones no visualizadas en el acróni...                  30
#
#    words_after_count
# 0                  1
# 1                 30
# 2                 30
# 3                 30
# 4                 20

# %%
law_mentions = df[df['entity_label'] == 'LAW_MENTION']
law_mentions['entity_text'].unique()
# Out:
# array(['Ley de Centros Penitenciarios de la Ciudad de México y demás normativa aplicable',
#        'Ley de Centros Penitenciarios de la Ciudad de México',
#        'Ley de Centros Penitenciarios', ...,
#        'Ley de Aguas Nacionales y demás disposiciones jurídicas aplicables',
#        'Ley de Procedimiento Administrativo del Distrito Federal y sus Reglamentos',
#        'Ley para Prevenir y Erradicar la Discriminación el Distrito Federal'],
#       dtype=object)

# %%
# Lista con solo los códigos de la Ciudad de México
leyes_completas = pd.read_csv('../../data/02_catalogs/leyes_hash.csv')
ley = leyes_completas[leyes_completas['nombre_normalized'].str.startswith('LEY', na=False)]
ley
# Out:
#                                                 nombre fecha_publicacion  \
# 1    Ley de Proteccion de Datos Personales en Poses...          03/10/08
# 2    Ley de Acceso de las Mujeres a una Vida Libre ...          25/06/25
# 3    Ley de los Derechos de Ninas Ninos y Adolescen...          02/04/25
# 4    Ley para el Reconocimiento y la Atencion de la...          31/03/25
# 5    Ley para la Celebracion de Espectaculos Public...          25/03/25
# ..                                                 ...               ...
# 641  Ley sobre el Escudo, la Bandera y el Himno Nac...          08/02/84
# 642      Ley sobre Elaboracion y Venta de Cafe Tostado          25/05/72
# 643  Ley sobre la Aprobacion de Tratados Internacio...          02/09/04
# 644               Ley sobre la Celebracion de Tratados          02/01/92
# 645  Ley sobre Refugiados, Proteccion Complementari...          27/01/11
#
#     fecha_actualizacion                                           link_pdf  \
# 1                   NaN  https://data.consejeria.cdmx.gob.mx//images/le...
# 2                   NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
# 3                   NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
# 4                   NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
# 5                   NaN  https://data.consejeria.cdmx.gob.mx/images/ley...
# ..                  ...                                                ...
# 641            01/04/24                                                NaN
# 642            10/12/04                                                NaN
# 643                 NaN                                                NaN
# 644            20/05/21                                                NaN
# 645            18/02/22                                                NaN
#
#                                              link_docx  \
# 1                                                  NaN
# 2    https://data.consejeria.cdmx.gob.mx/images/ley...
# 3    https://data.consejeria.cdmx.gob.mx/images/ley...
# 4    https://data.consejeria.cdmx.gob.mx/images/ley...
# 5    https://data.consejeria.cdmx.gob.mx/images/ley...
# ..                                                 ...
# 641                                                NaN
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
#
#                                             source_url gov_level  \
# 1    https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 2    https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 3    https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 4    https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# 5    https://data.consejeria.cdmx.gob.mx/index.php/...      CDMX
# ..                                                 ...       ...
# 641                                                NaN   FEDERAL
# 642                                                NaN   FEDERAL
# 643                                                NaN   FEDERAL
# 644                                                NaN   FEDERAL
# 645                                                NaN   FEDERAL
#
#                                      nombre_normalized    doc_id
# 1    LEYDEPROTECCIONDEDATOSPERSONALESENPOSESIONDESU...  80360428
# 2    LEYDEACCESODELASMUJERESAUNAVIDALIBREDEVIOLENCI...  74FF23BF
# 3    LEYDELOSDERECHOSDENINASNINOSYADOLESCENTESDELAC...  FB6CCCAE
# 4    LEYPARAELRECONOCIMIENTOYLAATENCIONDELASPERSONA...  6C800A8E
# 5    LEYPARALACELEBRACIONDEESPECTACULOSPUBLICOSDELA...  298E1252
# ..                                                 ...       ...
# 641        LEYSOBREELESCUDOLABANDERAYELHIMNONACIONALES  9DDF0C1E
# 642             LEYSOBREELABORACIONYVENTADECAFETOSTADO  761D1F2F
# 643  LEYSOBRELAAPROBACIONDETRATADOSINTERNACIONALESE...  90CCD942
# 644                    LEYSOBRELACELEBRACIONDETRATADOS  703EDD4C
# 645  LEYSOBREREFUGIADOSPROTECCIONCOMPLEMENTARIAYASI...  6A69150A
#
# [470 rows x 9 columns]

# %% [markdown]
# ## Filtrar menciones que ya tienen match con regex oficiales
#
# Antes de procesar con LLM (que es costoso), filtramos las menciones que ya pueden ser identificadas con los patrones de regex oficiales de CDMX y federales.

# %%
# Filtrar menciones que ya tienen match con regex
law_mentions_sin_match, law_mentions_con_match, stats = filter_official_regex_matches_parallel(
    df=law_mentions,
    entity_text_col='entity_text',
    n_jobs=None  # Usa todos los cores
)

# print(f"\n✓ Filtrado completado")
# print(f"  - Menciones CON match en regex: {stats['con_match_regex']}")
# print(f"  - Menciones SIN match (para LLM): {stats['sin_match_regex']}")
# Out:
# === FILTRANDO MENCIONES CON REGEX OFICIALES (PARALELO) ===
# Total de menciones a analizar: 4324
# Total de patrones regex a aplicar: 784
# Usando 8 procesos paralelos
# Procesando 8 chunks en paralelo...
# /opt/anaconda3/envs/cdmx_kg/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# === RESULTADOS DEL FILTRADO ===
# Total de menciones: 4324
# Con match en regex (filtradas): 1720
# Sin match en regex (para LLM): 2604
# Porcentaje filtrado: 39.8%
#
# === EJEMPLOS DE MENCIONES FILTRADAS (YA TIENEN MATCH) ===
# 1. Ley de Centros Penitenciarios de la Ciudad de México y demás normativa aplicable
#    Match: LEY DE CENTROS PENITENCIARIOS DE LA CIUDAD DE MÉXICO
# 2. Ley de Centros Penitenciarios de la Ciudad de México
#    Match: LEY DE CENTROS PENITENCIARIOS DE LA CIUDAD DE MÉXICO
# 3. Ley de Centros Penitenciarios de la Ciudad de México
#    Match: LEY DE CENTROS PENITENCIARIOS DE LA CIUDAD DE MÉXICO
# 4. Ley de Centros Penitenciarios de la Ciudad de México
#    Match: LEY DE CENTROS PENITENCIARIOS DE LA CIUDAD DE MÉXICO
# 5. Ley de Archivos de la Ciudad de México y demás normativa aplicable y sólo podrá
#    Match: LEY DE ARCHIVOS DE LA CIUDAD DE MÉXICO
#
# === EJEMPLOS DE MENCIONES SIN MATCH (PARA LLM) ===
# 1. Ley de Centros Penitenciarios
# 2. Ley de Centros Penitenciarios
# 3. Ley de Centros Penitenciarios y en la Ley Nacional
# 4. Ley de Centros Penitenciarios
# 5. Ley de Centros Penitenciarios

# %%
stats
# Out:
# {'total': 4324,
#  'con_match_regex': 1720,
#  'sin_match_regex': 2604,
#  'porcentaje_filtrado': 39.77798334875116}

# %% [markdown]
# ## Matching con OpenAI para menciones sin match
#
# Ahora procesamos con LLM solo las menciones que NO tuvieron match con los regex oficiales.

# %%
# Aplicar matching con OpenAI solo a las menciones SIN match en regex

# Matching deduplicado
results_df = apply_openai_law_matching_deduplicated(
    mentions_df=law_mentions_sin_match,
    cdmx_laws_df=ley,
    client=client,
    entity_text_col='entity_text',
    art_id_col='art_id',
    delay_seconds=1.5,  # Reducido de 1.0
    temperature=0.2
)

print(f"\nMatching con LLM completado. Total de resultados: {len(results_df)}")
# Out:
# === MATCHING DE LEYES CON OPENAI (OPTIMIZADO - DEDUPLICADO) ===
# Total de menciones (con duplicados): 2604
# Filas válidas: 2604 (de 2604 total)
#
# Menciones ÚNICAS a procesar: 1103
#  Reducción: 1501 llamadas ahorradas
# Ahorro de tiempo estimado: 37.5 minutos
# Tiempo estimado total: 27.6 minutos
# Leyes oficiales CDMX en catálogo: 470
# Temperatura del modelo: 0.2
#
# Procesando menciones únicas...
#   Progreso: 10/1103 menciones únicas procesadas
#   Tiempo transcurrido: 0.4 minutos
#   Tiempo restante estimado: 27.3 minutos
#
#   Progreso: 20/1103 menciones únicas procesadas
#   Tiempo transcurrido: 0.8 minutos
#   Tiempo restante estimado: 27.1 minutos
#
#   Progreso: 30/1103 menciones únicas procesadas
#   Tiempo transcurrido: 1.4 minutos
#   Tiempo restante estimado: 26.8 minutos
#
#   Progreso: 40/1103 menciones únicas procesadas
#   Tiempo transcurrido: 2.0 minutos
#   Tiempo restante estimado: 26.6 minutos
#
#   Progreso: 50/1103 menciones únicas procesadas
#   Tiempo transcurrido: 2.9 minutos
#   Tiempo restante estimado: 26.3 minutos
#
#   Progreso: 60/1103 menciones únicas procesadas
#   Tiempo transcurrido: 3.4 minutos
#   Tiempo restante estimado: 26.1 minutos
#
#   Progreso: 70/1103 menciones únicas procesadas
#   Tiempo transcurrido: 4.0 minutos
#   Tiempo restante estimado: 25.8 minutos
#
#   Progreso: 80/1103 menciones únicas procesadas
#   Tiempo transcurrido: 4.4 minutos
#   Tiempo restante estimado: 25.6 minutos
#
#   Progreso: 90/1103 menciones únicas procesadas
#   Tiempo transcurrido: 5.0 minutos
#   Tiempo restante estimado: 25.3 minutos
#
#   Progreso: 100/1103 menciones únicas procesadas
#   Tiempo transcurrido: 5.5 minutos
#   Tiempo restante estimado: 25.1 minutos
#
#   Progreso: 110/1103 menciones únicas procesadas
#   Tiempo transcurrido: 6.1 minutos
#   Tiempo restante estimado: 24.8 minutos
#
#   Progreso: 120/1103 menciones únicas procesadas
#   Tiempo transcurrido: 6.8 minutos
#   Tiempo restante estimado: 24.6 minutos
#
#   Progreso: 130/1103 menciones únicas procesadas
#   Tiempo transcurrido: 7.2 minutos
#   Tiempo restante estimado: 24.3 minutos
#
#   Progreso: 140/1103 menciones únicas procesadas
#   Tiempo transcurrido: 7.8 minutos
#   Tiempo restante estimado: 24.1 minutos
#
#   Progreso: 150/1103 menciones únicas procesadas
#   Tiempo transcurrido: 8.3 minutos
#   Tiempo restante estimado: 23.8 minutos
#
#   Progreso: 160/1103 menciones únicas procesadas
#   Tiempo transcurrido: 8.7 minutos
#   Tiempo restante estimado: 23.6 minutos
#
#   Progreso: 170/1103 menciones únicas procesadas
#   Tiempo transcurrido: 9.2 minutos
#   Tiempo restante estimado: 23.3 minutos
#
#   Progreso: 180/1103 menciones únicas procesadas
#   Tiempo transcurrido: 9.7 minutos
#   Tiempo restante estimado: 23.1 minutos
#
#   Progreso: 190/1103 menciones únicas procesadas
#   Tiempo transcurrido: 10.1 minutos
#   Tiempo restante estimado: 22.8 minutos
#
#   Progreso: 200/1103 menciones únicas procesadas
#   Tiempo transcurrido: 10.7 minutos
#   Tiempo restante estimado: 22.6 minutos
#
#   Progreso: 210/1103 menciones únicas procesadas
#   Tiempo transcurrido: 11.2 minutos
#   Tiempo restante estimado: 22.3 minutos
#
#   Progreso: 220/1103 menciones únicas procesadas
#   Tiempo transcurrido: 11.8 minutos
#   Tiempo restante estimado: 22.1 minutos
#
#   Progreso: 230/1103 menciones únicas procesadas
#   Tiempo transcurrido: 12.3 minutos
#   Tiempo restante estimado: 21.8 minutos
#
#   Progreso: 240/1103 menciones únicas procesadas
#   Tiempo transcurrido: 12.9 minutos
#   Tiempo restante estimado: 21.6 minutos
#
#   Progreso: 250/1103 menciones únicas procesadas
#   Tiempo transcurrido: 13.5 minutos
#   Tiempo restante estimado: 21.3 minutos
#
#   Progreso: 260/1103 menciones únicas procesadas
#   Tiempo transcurrido: 14.0 minutos
#   Tiempo restante estimado: 21.1 minutos
#
#   Progreso: 270/1103 menciones únicas procesadas
#   Tiempo transcurrido: 14.6 minutos
#   Tiempo restante estimado: 20.8 minutos
#
#   Progreso: 280/1103 menciones únicas procesadas
#   Tiempo transcurrido: 15.2 minutos
#   Tiempo restante estimado: 20.6 minutos
#
#   Progreso: 290/1103 menciones únicas procesadas
#   Tiempo transcurrido: 15.8 minutos
#   Tiempo restante estimado: 20.3 minutos
#
#   Progreso: 300/1103 menciones únicas procesadas
#   Tiempo transcurrido: 16.4 minutos
#   Tiempo restante estimado: 20.1 minutos
#
#   Progreso: 310/1103 menciones únicas procesadas
#   Tiempo transcurrido: 17.0 minutos
#   Tiempo restante estimado: 19.8 minutos
#
#   Progreso: 320/1103 menciones únicas procesadas
#   Tiempo transcurrido: 17.6 minutos
#   Tiempo restante estimado: 19.6 minutos
#
#   Progreso: 330/1103 menciones únicas procesadas
#   Tiempo transcurrido: 18.1 minutos
#   Tiempo restante estimado: 19.3 minutos
#
#   Progreso: 340/1103 menciones únicas procesadas
#   Tiempo transcurrido: 18.8 minutos
#   Tiempo restante estimado: 19.1 minutos
#
#   Progreso: 350/1103 menciones únicas procesadas
#   Tiempo transcurrido: 19.3 minutos
#   Tiempo restante estimado: 18.8 minutos
#
#   Progreso: 360/1103 menciones únicas procesadas
#   Tiempo transcurrido: 19.9 minutos
#   Tiempo restante estimado: 18.6 minutos
#
#   Progreso: 370/1103 menciones únicas procesadas
#   Tiempo transcurrido: 20.5 minutos
#   Tiempo restante estimado: 18.3 minutos
#
#   Progreso: 380/1103 menciones únicas procesadas
#   Tiempo transcurrido: 21.1 minutos
#   Tiempo restante estimado: 18.1 minutos
#
#   Progreso: 390/1103 menciones únicas procesadas
#   Tiempo transcurrido: 21.6 minutos
#   Tiempo restante estimado: 17.8 minutos
#
#   Progreso: 400/1103 menciones únicas procesadas
#   Tiempo transcurrido: 22.2 minutos
#   Tiempo restante estimado: 17.6 minutos
#
#   Progreso: 410/1103 menciones únicas procesadas
#   Tiempo transcurrido: 22.8 minutos
#   Tiempo restante estimado: 17.3 minutos
#
#   Progreso: 420/1103 menciones únicas procesadas
#   Tiempo transcurrido: 23.4 minutos
#   Tiempo restante estimado: 17.1 minutos
#
#   Progreso: 430/1103 menciones únicas procesadas
#   Tiempo transcurrido: 24.0 minutos
#   Tiempo restante estimado: 16.8 minutos
#
#   Progreso: 440/1103 menciones únicas procesadas
#   Tiempo transcurrido: 24.6 minutos
#   Tiempo restante estimado: 16.6 minutos
#
#   Progreso: 450/1103 menciones únicas procesadas
#   Tiempo transcurrido: 25.2 minutos
#   Tiempo restante estimado: 16.3 minutos
#
#   Progreso: 460/1103 menciones únicas procesadas
#   Tiempo transcurrido: 25.7 minutos
#   Tiempo restante estimado: 16.1 minutos
#
#   Progreso: 470/1103 menciones únicas procesadas
#   Tiempo transcurrido: 26.3 minutos
#   Tiempo restante estimado: 15.8 minutos
#
#   Progreso: 480/1103 menciones únicas procesadas
#   Tiempo transcurrido: 27.0 minutos
#   Tiempo restante estimado: 15.6 minutos
#
#   Progreso: 490/1103 menciones únicas procesadas
#   Tiempo transcurrido: 27.6 minutos
#   Tiempo restante estimado: 15.3 minutos
#
#   Progreso: 500/1103 menciones únicas procesadas
#   Tiempo transcurrido: 28.2 minutos
#   Tiempo restante estimado: 15.1 minutos
#
#   Progreso: 510/1103 menciones únicas procesadas
#   Tiempo transcurrido: 28.7 minutos
#   Tiempo restante estimado: 14.8 minutos
#
#   Progreso: 520/1103 menciones únicas procesadas
#   Tiempo transcurrido: 29.2 minutos
#   Tiempo restante estimado: 14.6 minutos
#
#   Progreso: 530/1103 menciones únicas procesadas
#   Tiempo transcurrido: 29.8 minutos
#   Tiempo restante estimado: 14.3 minutos
#
#   Progreso: 540/1103 menciones únicas procesadas
#   Tiempo transcurrido: 30.4 minutos
#   Tiempo restante estimado: 14.1 minutos
#
#   Progreso: 550/1103 menciones únicas procesadas
#   Tiempo transcurrido: 30.9 minutos
#   Tiempo restante estimado: 13.8 minutos
#
#   Progreso: 560/1103 menciones únicas procesadas
#   Tiempo transcurrido: 31.5 minutos
#   Tiempo restante estimado: 13.6 minutos
#
#   Progreso: 570/1103 menciones únicas procesadas
#   Tiempo transcurrido: 32.1 minutos
#   Tiempo restante estimado: 13.3 minutos
#
#   Progreso: 580/1103 menciones únicas procesadas
#   Tiempo transcurrido: 32.7 minutos
#   Tiempo restante estimado: 13.1 minutos
#
#   Progreso: 590/1103 menciones únicas procesadas
#   Tiempo transcurrido: 33.3 minutos
#   Tiempo restante estimado: 12.8 minutos
#
#   Progreso: 600/1103 menciones únicas procesadas
#   Tiempo transcurrido: 33.9 minutos
#   Tiempo restante estimado: 12.6 minutos
#
#   Progreso: 610/1103 menciones únicas procesadas
#   Tiempo transcurrido: 34.4 minutos
#   Tiempo restante estimado: 12.3 minutos
#
#   Progreso: 620/1103 menciones únicas procesadas
#   Tiempo transcurrido: 35.0 minutos
#   Tiempo restante estimado: 12.1 minutos
#
#   Progreso: 630/1103 menciones únicas procesadas
#   Tiempo transcurrido: 35.6 minutos
#   Tiempo restante estimado: 11.8 minutos
#
#   Progreso: 640/1103 menciones únicas procesadas
#   Tiempo transcurrido: 36.2 minutos
#   Tiempo restante estimado: 11.6 minutos
#
#   Progreso: 650/1103 menciones únicas procesadas
#   Tiempo transcurrido: 36.8 minutos
#   Tiempo restante estimado: 11.3 minutos
#
#   Progreso: 660/1103 menciones únicas procesadas
#   Tiempo transcurrido: 37.4 minutos
#   Tiempo restante estimado: 11.1 minutos
#
#   Progreso: 670/1103 menciones únicas procesadas
#   Tiempo transcurrido: 38.0 minutos
#   Tiempo restante estimado: 10.8 minutos
#
#   Progreso: 680/1103 menciones únicas procesadas
#   Tiempo transcurrido: 38.5 minutos
#   Tiempo restante estimado: 10.6 minutos
#
#   Progreso: 690/1103 menciones únicas procesadas
#   Tiempo transcurrido: 39.1 minutos
#   Tiempo restante estimado: 10.3 minutos
#
#   Progreso: 700/1103 menciones únicas procesadas
#   Tiempo transcurrido: 39.7 minutos
#   Tiempo restante estimado: 10.1 minutos
#
#   Progreso: 710/1103 menciones únicas procesadas
#   Tiempo transcurrido: 40.2 minutos
#   Tiempo restante estimado: 9.8 minutos
#
#   Progreso: 720/1103 menciones únicas procesadas
#   Tiempo transcurrido: 40.8 minutos
#   Tiempo restante estimado: 9.6 minutos
#
#   Progreso: 730/1103 menciones únicas procesadas
#   Tiempo transcurrido: 41.4 minutos
#   Tiempo restante estimado: 9.3 minutos
#
#   Progreso: 740/1103 menciones únicas procesadas
#   Tiempo transcurrido: 42.0 minutos
#   Tiempo restante estimado: 9.1 minutos
#
#   Progreso: 750/1103 menciones únicas procesadas
#   Tiempo transcurrido: 42.6 minutos
#   Tiempo restante estimado: 8.8 minutos
#
#   Progreso: 760/1103 menciones únicas procesadas
#   Tiempo transcurrido: 43.3 minutos
#   Tiempo restante estimado: 8.6 minutos
#
#   Progreso: 770/1103 menciones únicas procesadas
#   Tiempo transcurrido: 43.8 minutos
#   Tiempo restante estimado: 8.3 minutos
#
#   Progreso: 780/1103 menciones únicas procesadas
#   Tiempo transcurrido: 44.3 minutos
#   Tiempo restante estimado: 8.1 minutos
#
#   Progreso: 790/1103 menciones únicas procesadas
#   Tiempo transcurrido: 44.9 minutos
#   Tiempo restante estimado: 7.8 minutos
#
#   Progreso: 800/1103 menciones únicas procesadas
#   Tiempo transcurrido: 45.4 minutos
#   Tiempo restante estimado: 7.6 minutos
#
#   Progreso: 810/1103 menciones únicas procesadas
#   Tiempo transcurrido: 47.9 minutos
#   Tiempo restante estimado: 7.3 minutos
#
#   Progreso: 820/1103 menciones únicas procesadas
#   Tiempo transcurrido: 48.4 minutos
#   Tiempo restante estimado: 7.1 minutos
#
#   Progreso: 830/1103 menciones únicas procesadas
#   Tiempo transcurrido: 49.1 minutos
#   Tiempo restante estimado: 6.8 minutos
#
#   Progreso: 840/1103 menciones únicas procesadas
#   Tiempo transcurrido: 49.8 minutos
#   Tiempo restante estimado: 6.6 minutos
#
#   Progreso: 850/1103 menciones únicas procesadas
#   Tiempo transcurrido: 50.2 minutos
#   Tiempo restante estimado: 6.3 minutos
#
#   Progreso: 860/1103 menciones únicas procesadas
#   Tiempo transcurrido: 50.9 minutos
#   Tiempo restante estimado: 6.1 minutos
#
#   Progreso: 870/1103 menciones únicas procesadas
#   Tiempo transcurrido: 51.5 minutos
#   Tiempo restante estimado: 5.8 minutos
#
#   Progreso: 880/1103 menciones únicas procesadas
#   Tiempo transcurrido: 52.0 minutos
#   Tiempo restante estimado: 5.6 minutos
#
#   Progreso: 890/1103 menciones únicas procesadas
#   Tiempo transcurrido: 52.6 minutos
#   Tiempo restante estimado: 5.3 minutos
#
#   Progreso: 900/1103 menciones únicas procesadas
#   Tiempo transcurrido: 53.1 minutos
#   Tiempo restante estimado: 5.1 minutos
#
#   Progreso: 910/1103 menciones únicas procesadas
#   Tiempo transcurrido: 53.5 minutos
#   Tiempo restante estimado: 4.8 minutos
#
#   Progreso: 920/1103 menciones únicas procesadas
#   Tiempo transcurrido: 54.0 minutos
#   Tiempo restante estimado: 4.6 minutos
#
#   Progreso: 930/1103 menciones únicas procesadas
#   Tiempo transcurrido: 54.4 minutos
#   Tiempo restante estimado: 4.3 minutos
#
#   Progreso: 940/1103 menciones únicas procesadas
#   Tiempo transcurrido: 54.8 minutos
#   Tiempo restante estimado: 4.1 minutos
#
#   Progreso: 950/1103 menciones únicas procesadas
#   Tiempo transcurrido: 55.3 minutos
#   Tiempo restante estimado: 3.8 minutos
#
#   Progreso: 960/1103 menciones únicas procesadas
#   Tiempo transcurrido: 55.9 minutos
#   Tiempo restante estimado: 3.6 minutos
#
#   Progreso: 970/1103 menciones únicas procesadas
#   Tiempo transcurrido: 56.5 minutos
#   Tiempo restante estimado: 3.3 minutos
#
#   Progreso: 980/1103 menciones únicas procesadas
#   Tiempo transcurrido: 57.1 minutos
#   Tiempo restante estimado: 3.1 minutos
#
#   Progreso: 990/1103 menciones únicas procesadas
#   Tiempo transcurrido: 57.6 minutos
#   Tiempo restante estimado: 2.8 minutos
#
#   Progreso: 1000/1103 menciones únicas procesadas
#   Tiempo transcurrido: 58.2 minutos
#   Tiempo restante estimado: 2.6 minutos
#
#   Progreso: 1010/1103 menciones únicas procesadas
#   Tiempo transcurrido: 58.8 minutos
#   Tiempo restante estimado: 2.3 minutos
#
#   Progreso: 1020/1103 menciones únicas procesadas
#   Tiempo transcurrido: 59.4 minutos
#   Tiempo restante estimado: 2.1 minutos
#
#   Progreso: 1030/1103 menciones únicas procesadas
#   Tiempo transcurrido: 60.0 minutos
#   Tiempo restante estimado: 1.8 minutos
#
#   Progreso: 1040/1103 menciones únicas procesadas
#   Tiempo transcurrido: 61.1 minutos
#   Tiempo restante estimado: 1.6 minutos
#
#   Progreso: 1050/1103 menciones únicas procesadas
#   Tiempo transcurrido: 61.6 minutos
#   Tiempo restante estimado: 1.3 minutos
#
#   Progreso: 1060/1103 menciones únicas procesadas
#   Tiempo transcurrido: 62.2 minutos
#   Tiempo restante estimado: 1.1 minutos
#
#   Progreso: 1070/1103 menciones únicas procesadas
#   Tiempo transcurrido: 62.6 minutos
#   Tiempo restante estimado: 0.8 minutos
#
#   Progreso: 1080/1103 menciones únicas procesadas
#   Tiempo transcurrido: 63.2 minutos
#   Tiempo restante estimado: 0.6 minutos
#
#   Progreso: 1090/1103 menciones únicas procesadas
#   Tiempo transcurrido: 63.6 minutos
#   Tiempo restante estimado: 0.3 minutos
#
#   Progreso: 1100/1103 menciones únicas procesadas
#   Tiempo transcurrido: 64.5 minutos
#   Tiempo restante estimado: 0.1 minutos
#
#
# ✓ Procesamiento de menciones únicas completado
#   Total procesado: 1103 menciones únicas
#
# Mapeando resultados a todas las 2604 filas originales...
#
# === ESTADÍSTICAS FINALES ===
# Total de filas con resultados: 2604
# Menciones únicas procesadas: 1103
# Matches seguros: 2196 (84.3%)
# Matches ambiguos: 0 (0.0%)
# Sin matches: 404 (15.5%)
# Errores: 4 (0.2%)
#
# Tasa de éxito general: 84.3%
# Con doc_id válido: 2196 (84.3%)
# Sin doc_id: 408 (15.7%)
#
# Tiempo total: 64.7 minutos
# ⚡ Velocidad: 17.1 menciones únicas/minuto
#
# Matching con LLM completado. Total de resultados: 2604

# %%
results_df.to_csv('../../data/04_matched/law_mentions_matched.csv', index=False)
